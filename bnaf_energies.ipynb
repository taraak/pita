# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !pip install torchsde
# !pip install torch==2.0.1+cu118 --index-url https://download.pytorch.org/whl/cu118
# Out:
# Collecting torchsde
#   Downloading torchsde-0.2.6-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19 in /home/ray/anaconda3/lib/python3.9/site-packages (from torchsde) (1.25.2)
# Requirement already satisfied: scipy>=1.5 in /home/ray/anaconda3/lib/python3.9/site-packages (from torchsde) (1.11.1)
# Requirement already satisfied: torch>=1.6.0 in /home/ray/anaconda3/lib/python3.9/site-packages (from torchsde) (2.0.1+cu118)
# Collecting trampoline>=0.1.2 (from torchsde)
#   Downloading trampoline-0.1.2-py3-none-any.whl (5.2 kB)
# Requirement already satisfied: filelock in /home/ray/anaconda3/lib/python3.9/site-packages (from torch>=1.6.0->torchsde) (3.12.2)
# Requirement already satisfied: typing-extensions in /home/ray/anaconda3/lib/python3.9/site-packages (from torch>=1.6.0->torchsde) (4.7.1)
# Requirement already satisfied: sympy in /home/ray/anaconda3/lib/python3.9/site-packages (from torch>=1.6.0->torchsde) (1.12)
# Requirement already satisfied: networkx in /home/ray/anaconda3/lib/python3.9/site-packages (from torch>=1.6.0->torchsde) (3.1)
# Requirement already satisfied: jinja2 in /home/ray/anaconda3/lib/python3.9/site-packages (from torch>=1.6.0->torchsde) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /home/ray/anaconda3/lib/python3.9/site-packages (from torch>=1.6.0->torchsde) (2.0.0)
# Requirement already satisfied: cmake in /home/ray/anaconda3/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.6.0->torchsde) (3.27.6)
# Requirement already satisfied: lit in /home/ray/anaconda3/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.6.0->torchsde) (17.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ray/anaconda3/lib/python3.9/site-packages (from jinja2->torch>=1.6.0->torchsde) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/ray/anaconda3/lib/python3.9/site-packages (from sympy->torch>=1.6.0->torchsde) (1.3.0)
# Installing collected packages: trampoline, torchsde
# Successfully installed torchsde-0.2.6 trampoline-0.1.2
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch==2.0.1+cu118 in /home/ray/anaconda3/lib/python3.9/site-packages (2.0.1+cu118)
# Requirement already satisfied: filelock in /home/ray/anaconda3/lib/python3.9/site-packages (from torch==2.0.1+cu118) (3.12.2)
# Requirement already satisfied: typing-extensions in /home/ray/anaconda3/lib/python3.9/site-packages (from torch==2.0.1+cu118) (4.7.1)
# Requirement already satisfied: sympy in /home/ray/anaconda3/lib/python3.9/site-packages (from torch==2.0.1+cu118) (1.12)
# Requirement already satisfied: networkx in /home/ray/anaconda3/lib/python3.9/site-packages (from torch==2.0.1+cu118) (3.1)
# Requirement already satisfied: jinja2 in /home/ray/anaconda3/lib/python3.9/site-packages (from torch==2.0.1+cu118) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /home/ray/anaconda3/lib/python3.9/site-packages (from torch==2.0.1+cu118) (2.0.0)
# Requirement already satisfied: cmake in /home/ray/anaconda3/lib/python3.9/site-packages (from triton==2.0.0->torch==2.0.1+cu118) (3.27.6)
# Requirement already satisfied: lit in /home/ray/anaconda3/lib/python3.9/site-packages (from triton==2.0.0->torch==2.0.1+cu118) (17.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ray/anaconda3/lib/python3.9/site-packages (from jinja2->torch==2.0.1+cu118) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/ray/anaconda3/lib/python3.9/site-packages (from sympy->torch==2.0.1+cu118) (1.3.0)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import torch
import torchsde
import numpy as np

# %%
        
def estimate_grad_Rt(x, t, beta=1.0, num_mc_samples=100):
    def grad_fxn(_x, _t):
        repeated_x = _x.unsqueeze(0).repeat_interleave(num_mc_samples, dim=0)
        repeated_t = _t.unsqueeze(0).repeat_interleave(num_mc_samples, dim=0)
        h_t = beta * repeated_t
        
        # samples = repeated_x + torch.normal(torch.zeros_like(repeated_x), h_t.unsqueeze(1) ** 0.5)
        samples = repeated_x + torch.randn(repeated_x.shape).to(device) * h_t.unsqueeze(1) ** 0.5
        log_rewards = target_distrib.energy(samples)#unnormalize(samples, global_mins, global_maxs))
        
        #import pdb; pdb.set_trace()
        return torch.logsumexp(log_rewards, dim=-1) - np.log(num_mc_samples)
    
    t = t * torch.ones(x.shape[0]).to(device)
    est_scores = torch.vmap(torch.func.grad(grad_fxn), randomness='different')(x, t)
    print(est_scores.max(-1)[0].mean())
    return est_scores#.clamp(min=-100.0, max=100.0)

def estimate_grad_Rt_vp(x, t, num_mc_samples=100):
    def grad_fxn(_x, _t):
        h_t = _t.repeat_interleave(num_mc_samples).unsqueeze(1)# / global_maxs
        repeated_x = _x.unsqueeze(0).repeat_interleave(num_mc_samples, dim=0)
        repeated_t = _t.unsqueeze(0).repeat_interleave(num_mc_samples, dim=0)
        
        samples = (repeated_x / (1 - repeated_t).sqrt().unsqueeze(1)) + (torch.normal(torch.zeros_like(repeated_x), h_t.sqrt()).to(device))
        log_rewards = target_distrib.log_prob(samples)#unnormalize(samples, global_mins, global_maxs))
        
        return torch.logsumexp(log_rewards, dim=-1) - np.log(num_mc_samples)
    
    t = t * torch.ones(x.shape[0]).to(device)
    est_scores = torch.vmap(torch.func.grad(grad_fxn), randomness='different')(x, t)
    return est_scores.clamp(min=-100.0, max=100.0)

def true_Rt(x,  h_t):
    target_distrib.convolve(h_t[0])# * (50 ** 2))
    energy = target_distrib.log_prob(x)#unnormalize(x, global_mins, global_maxs))
    target_distrib.reset()
    return energy

def true_Rt_vp(x, h_t):
    target_distrib.convolve(h_t)
    energy = target_distrib.log_prob(x / (1 - h_t).sqrt())#unnormalize(x / (1 - t).sqrt(), global_mins, global_maxs))
    target_distrib.reset()
    return energy

def true_grad_Rt(x, h_t):
    with torch.enable_grad():
        x.requires_grad_()
        samples_energy = true_Rt(x, h_t)
        true_scores = torch.autograd.grad(samples_energy.sum(), x, retain_graph=True)[0].detach()
    return true_scores.detach()

def true_grad_Rt_vp(x, h_t, global_mins=-50, global_maxs=50):
    samples_energy = true_Rt_vp(x, h_t)
    true_scores = torch.autograd.grad(samples_energy.sum(), x, retain_graph=True)[0].detach()
    return true_scores
        
def reward_matching_loss(target, vectorfield, constant_noise_scale, x, t):     
    t = t.unsqueeze(1)
    h_t = constant_noise_scale * t
    
    x.requires_grad = True

    # noisy sample: x(t)
    noisy_x = torch.normal(x, h_t ** 0.5)
    pred_scores = vectorfield(noisy_x, t.squeeze())

    estimated_scores = estimate_grad_Rt(noisy_x, t.squeeze(1), beta, 100)
    return ((estimated_scores - pred_scores)**2).mean()

# %%
def w1(x):
    return ((2 * np.pi * x[..., 0]) / 4.0).sin()

def w2(x):
    exp_arg = -0.5 * ((x[..., 0] - 1) / 0.6).pow(2)
    return 3 * exp_arg.exp()

def w3(x):
    def sigmoid(v):
        return 1 / (1 + (-v).exp())
    
    return 3 * sigmoid((x[..., 0] - 1) / 0.3)

def parenthesis_energy(x):
    two_norm = torch.linalg.norm(x, ord=2, dim=-1)
    first_term = 0.5 * ((two_norm - 2) / 0.4).pow(2)
    
    first_exp_arg_term = -0.5 * ((x[..., 0] - 2) / 0.6).pow(2)
    second_exp_arg_term = -0.5 * ((x[..., 0] + 2) / 0.6).pow(2)
    
    ln_term = torch.stack([first_exp_arg_term, second_exp_arg_term]).logsumexp(0)
    
    return first_term - ln_term

def contiguous_squiglies_energy(x):
    return 0.5 * ((x[..., 1] - w1(x)) / 0.4).pow(2)

def middle_divergent_squiglies_energy(x):
    first_exp_arg = -0.5 * ((x[..., 1] - w1(x)) / 0.35).pow(2)
    scnd_exp_arg = -0.5 * ((x[..., 1] - w1(x) + w2(x)) / 0.35).pow(2)
    
    return -torch.stack([first_exp_arg, scnd_exp_arg]).logsumexp(0)

def end_divergent_squiglies_energy(x):
    first_exp_arg = -0.5 * ((x[..., 1] - w1(x)) / 0.4).pow(2)
    scnd_exp_arg = -0.5 * ((x[..., 1] - w1(x) + w3(x)) / 0.35).pow(2)
    
    return -torch.stack([first_exp_arg, scnd_exp_arg]).logsumexp(0)

class EnergyDistribution:
    def __init__(self, energy_fxn):
        self.energy_fxn = energy_fxn
        
    def energy(self, x):
        return -self.energy_fxn(x)
    
class VEReverseSDE(torch.nn.Module):
    noise_type = 'diagonal'
    sde_type = 'ito'
    
    def __init__(self, score_net):
        super().__init__()
        self.score_model = score_net
    
    def f(self, t, x):
        # pdb.set_trace()
        t = t.repeat(len(x)).to(x.device)
        score = self.score_model(x, 1-t)
        return self.g(t, x).pow(2) * score 
    
    def g(self, t, x):
        return torch.full_like(x, beta ** 0.5) #+ 0.1

# %%
target_distrib = EnergyDistribution(contiguous_squiglies_energy)

# %%
num_mc_samples = 10
device = torch.device('cpu')

def est_ve_score_wrapper(x, t):
    with torch.enable_grad():
        return estimate_grad_Rt(x, t, beta=beta, num_mc_samples=1000)

ve_sde_est_score = VEReverseSDE(est_ve_score_wrapper)

beta = 40.0
num_samples = 1000
x1_samples = torch.randn((num_samples, 2)) * beta

# %%
t = torch.linspace(0.0, 1.0, 500)
with torch.no_grad():
    est_samples = torchsde.sdeint(ve_sde_est_score, x1_samples, t, method='euler')
# Out:
# tensor(60.9182)
# tensor(59.0613)
# tensor(51.8459)
# tensor(32.6450)
# tensor(27.6173)
# tensor(20.8187)
# tensor(17.2524)
# tensor(11.5707)
# tensor(9.7494)
# tensor(6.6325)
# tensor(6.5244)
# tensor(5.0616)
# tensor(4.0987)
# tensor(3.4386)
# tensor(3.4342)
# tensor(3.2770)
# tensor(2.6044)
# tensor(2.5946)
# tensor(2.5443)
# tensor(2.0609)
# tensor(1.9744)
# tensor(1.7316)
# tensor(1.8941)
# tensor(1.7207)
# tensor(1.6402)
# tensor(1.5335)
# tensor(1.6300)
# tensor(1.5883)
# tensor(1.6327)
# tensor(1.2260)
# tensor(1.4389)
# tensor(1.3530)
# tensor(1.3245)
# tensor(1.1856)
# tensor(1.2036)
# tensor(0.9563)
# tensor(1.2796)
# tensor(1.3048)
# tensor(1.2535)
# tensor(1.2163)
# tensor(1.0982)
# tensor(1.0516)
# tensor(1.4005)
# tensor(1.0585)
# tensor(0.9413)
# tensor(1.0245)
# tensor(1.0503)
# tensor(1.0210)
# tensor(0.9272)
# tensor(1.0064)
# tensor(0.9507)
# tensor(0.9093)
# tensor(0.8861)
# tensor(1.0306)
# tensor(0.8855)
# tensor(0.9042)
# tensor(0.7764)
# tensor(0.9641)
# tensor(0.7415)
# tensor(0.7917)
# tensor(0.8518)
# tensor(0.8155)
# tensor(0.8421)
# tensor(0.7927)
# tensor(0.8528)
# tensor(0.9020)
# tensor(0.7283)
# tensor(0.8096)
# tensor(0.6499)
# tensor(0.6757)
# tensor(0.7560)
# tensor(0.8226)
# tensor(0.8269)
# tensor(0.7963)
# tensor(0.7735)
# tensor(0.7094)
# tensor(0.7563)
# tensor(0.7191)
# tensor(0.7393)
# tensor(0.7333)
# tensor(0.7780)
# tensor(0.6639)
# tensor(0.6931)
# tensor(0.7530)
# tensor(0.7415)
# tensor(0.6200)
# tensor(0.6854)
# tensor(0.7905)
# tensor(0.6866)
# tensor(0.6509)
# tensor(0.6348)
# tensor(0.7635)
# tensor(0.7526)
# tensor(0.7235)
# tensor(0.6270)
# tensor(0.6911)
# tensor(0.5557)
# tensor(0.6492)
# tensor(0.7651)
# tensor(0.5654)
# tensor(0.5797)
# tensor(0.5634)
# tensor(0.6432)
# tensor(0.6255)
# tensor(0.5765)
# tensor(0.6482)
# tensor(0.5045)
# tensor(0.5907)
# tensor(0.5361)
# tensor(0.6576)
# tensor(0.5900)
# tensor(0.5848)
# tensor(0.6385)
# tensor(0.6445)
# tensor(0.6637)
# tensor(0.6314)
# tensor(0.5538)
# tensor(0.6169)
# tensor(0.5830)
# tensor(0.6183)
# tensor(0.5625)
# tensor(0.5830)
# tensor(0.5709)
# tensor(0.6386)
# tensor(0.5533)
# tensor(0.5117)
# tensor(0.5895)
# tensor(0.5488)
# tensor(0.5920)
# tensor(0.5143)
# tensor(0.5702)
# tensor(0.4875)
# tensor(0.5474)
# tensor(0.5678)
# tensor(0.6148)
# tensor(0.6512)
# tensor(0.5225)
# tensor(0.4762)
# tensor(0.5163)
# tensor(0.5543)
# tensor(0.5102)
# tensor(0.4714)
# tensor(0.5219)
# tensor(0.4686)
# tensor(0.5125)
# tensor(0.4972)
# tensor(0.4975)
# tensor(0.5209)
# tensor(0.4823)
# tensor(0.4957)
# tensor(0.5158)
# tensor(0.4596)
# tensor(0.4968)
# tensor(0.4629)
# tensor(0.4691)
# tensor(0.5218)
# tensor(0.5476)
# tensor(0.5491)
# tensor(0.4905)
# tensor(0.5465)
# tensor(0.4672)
# tensor(0.4366)
# tensor(0.5261)
# tensor(0.4932)
# tensor(0.5123)
# tensor(0.5104)
# tensor(0.4608)
# tensor(0.5143)
# tensor(0.4481)
# tensor(0.4564)
# tensor(0.5157)
# tensor(0.4736)
# tensor(0.5152)
# tensor(0.5231)
# tensor(0.5182)
# tensor(0.4134)
# tensor(0.5081)
# tensor(0.4580)
# tensor(0.4859)
# tensor(0.4243)
# tensor(0.4567)
# tensor(0.4398)
# tensor(0.4849)
# tensor(0.5349)
# tensor(0.5289)
# tensor(0.4086)
# tensor(0.5018)
# tensor(0.4376)
# tensor(0.4758)
# tensor(0.4294)
# tensor(0.4786)
# tensor(0.4582)
# tensor(0.3738)
# tensor(0.4008)
# tensor(0.4233)
# tensor(0.4640)
# tensor(0.4506)
# tensor(0.4787)
# tensor(0.4406)
# tensor(0.4913)
# tensor(0.4242)
# tensor(0.4523)
# tensor(0.4435)
# tensor(0.4592)
# tensor(0.4012)
# tensor(0.4582)
# tensor(0.4669)
# tensor(0.4219)
# tensor(0.4345)
# tensor(0.4367)
# tensor(0.4732)
# tensor(0.4505)
# tensor(0.4166)
# tensor(0.3847)
# tensor(0.4434)
# tensor(0.3943)
# tensor(0.4317)
# tensor(0.4210)
# tensor(0.4299)
# tensor(0.4377)
# tensor(0.3806)
# tensor(0.4299)
# tensor(0.4419)
# tensor(0.4633)
# tensor(0.4915)
# tensor(0.3660)
# tensor(0.4457)
# tensor(0.4106)
# tensor(0.4106)
# tensor(0.4153)
# tensor(0.3801)
# tensor(0.4611)
# tensor(0.4190)
# tensor(0.3944)
# tensor(0.4140)
# tensor(0.4466)
# tensor(0.3422)
# tensor(0.4033)
# tensor(0.4063)
# tensor(0.3746)
# tensor(0.4179)
# tensor(0.3664)
# tensor(0.4076)
# tensor(0.3685)
# tensor(0.4038)
# tensor(0.4454)
# tensor(0.4075)
# tensor(0.3499)
# tensor(0.3884)
# tensor(0.4166)
# tensor(0.3953)
# tensor(0.3870)
# tensor(0.4118)
# tensor(0.3958)
# tensor(0.3586)
# tensor(0.3484)
# tensor(0.3768)
# tensor(0.3597)
# tensor(0.3257)
# tensor(0.3977)
# tensor(0.3850)
# tensor(0.3684)
# tensor(0.3627)
# tensor(0.4113)
# tensor(0.3503)
# tensor(0.3799)
# tensor(0.4414)
# tensor(0.4327)
# tensor(0.3804)
# tensor(0.4454)
# tensor(0.3742)
# tensor(0.3834)
# tensor(0.3883)
# tensor(0.3804)
# tensor(0.4085)
# tensor(0.3838)
# tensor(0.3844)
# tensor(0.3549)
# tensor(0.3960)
# tensor(0.3785)
# tensor(0.3575)
# tensor(0.4184)
# tensor(0.3639)
# tensor(0.3554)
# tensor(0.4101)
# tensor(0.3689)
# tensor(0.3371)
# tensor(0.3501)
# tensor(0.3759)
# tensor(0.3434)
# tensor(0.3518)
# tensor(0.3667)
# tensor(0.3533)
# tensor(0.3448)
# tensor(0.4124)
# tensor(0.3609)
# tensor(0.3581)
# tensor(0.3308)
# tensor(0.3769)
# tensor(0.3371)
# tensor(0.3748)
# tensor(0.3725)
# tensor(0.3602)
# tensor(0.4082)
# tensor(0.3664)
# tensor(0.3547)
# tensor(0.3807)
# tensor(0.3060)
# tensor(0.3543)
# tensor(0.3407)
# tensor(0.3886)
# tensor(0.3688)
# tensor(0.3771)
# tensor(0.3528)
# tensor(0.3126)
# tensor(0.3267)
# tensor(0.3662)
# tensor(0.3549)
# tensor(0.3399)
# tensor(0.3171)
# tensor(0.3825)
# tensor(0.3649)
# tensor(0.3439)
# tensor(0.3458)
# tensor(0.3309)
# tensor(0.3283)
# tensor(0.3462)
# tensor(0.3313)
# tensor(0.3543)
# tensor(0.3592)
# tensor(0.3246)
# tensor(0.3327)
# tensor(0.3462)
# tensor(0.3384)
# tensor(0.3038)
# tensor(0.3433)
# tensor(0.3219)
# tensor(0.3413)
# tensor(0.3320)
# tensor(0.3209)
# tensor(0.3576)
# tensor(0.3101)
# tensor(0.3465)
# tensor(0.3380)
# tensor(0.3291)
# tensor(0.3168)
# tensor(0.3365)
# tensor(0.3227)
# tensor(0.3371)
# tensor(0.2829)
# tensor(0.3229)
# tensor(0.3420)
# tensor(0.3315)
# tensor(0.3190)
# tensor(0.3068)
# tensor(0.3190)
# tensor(0.2914)
# tensor(0.2831)
# tensor(0.3542)
# tensor(0.3360)
# tensor(0.3096)
# tensor(0.3400)
# tensor(0.3184)
# tensor(0.2975)
# tensor(0.3013)
# tensor(0.2902)
# tensor(0.3246)
# tensor(0.3170)
# tensor(0.3395)
# tensor(0.3059)
# tensor(0.2967)
# tensor(0.3242)
# tensor(0.3470)
# tensor(0.3189)
# tensor(0.3233)
# tensor(0.2470)
# tensor(0.3068)
# tensor(0.2921)
# tensor(0.2933)
# tensor(0.3276)
# tensor(0.3177)
# tensor(0.2963)
# tensor(0.2671)
# tensor(0.3303)
# tensor(0.2806)
# tensor(0.2842)
# tensor(0.3084)
# tensor(0.2998)
# tensor(0.3467)
# tensor(0.3088)
# tensor(0.2980)
# tensor(0.2928)
# tensor(0.2996)
# tensor(0.2938)
# tensor(0.3265)
# tensor(0.3281)
# tensor(0.2766)
# tensor(0.2908)
# tensor(0.2992)
# tensor(0.3124)
# tensor(0.3253)
# tensor(0.2841)
# tensor(0.2987)
# tensor(0.2882)
# tensor(0.3366)
# tensor(0.3392)
# tensor(0.2640)
# tensor(0.2805)
# tensor(0.2665)
# tensor(0.2695)
# tensor(0.3281)
# tensor(0.3426)
# tensor(0.2921)
# tensor(0.2675)
# tensor(0.2813)
# tensor(0.2994)
# tensor(0.2823)
# tensor(0.2823)
# tensor(0.2796)
# tensor(0.2890)
# tensor(0.2784)
# tensor(0.2656)
# tensor(0.3034)
# tensor(0.3143)
# tensor(0.2821)
# tensor(0.2650)
# tensor(0.2919)
# tensor(0.3007)
# tensor(0.3026)
# tensor(0.2785)
# tensor(0.2938)
# tensor(0.3150)
# tensor(0.2985)
# tensor(0.2639)
# tensor(0.3127)
# tensor(0.2686)
# tensor(0.2768)
# tensor(0.2618)
# tensor(0.2783)
# tensor(0.3124)
# tensor(0.3147)
# tensor(0.2902)
# tensor(0.3145)
# tensor(0.3137)
# tensor(0.2582)
# tensor(0.2967)
# tensor(0.2772)
# tensor(0.2853)
# tensor(0.3040)
# tensor(0.2968)
# tensor(0.2942)
# tensor(0.2481)
# tensor(0.2905)
# tensor(0.2968)
# tensor(0.2783)
# tensor(0.2982)
# tensor(0.2709)
# tensor(0.2891)
# tensor(0.2705)
# tensor(0.2659)
# tensor(0.2994)
# tensor(0.2499)
# tensor(0.2473)
# tensor(0.2898)
# tensor(0.2493)
# tensor(0.2873)
# tensor(0.2298)
# tensor(0.2815)
# tensor(0.2828)
# tensor(0.2831)
# tensor(0.2782)
# tensor(0.2699)
# tensor(0.2718)
# tensor(0.2562)
# tensor(0.2865)
# tensor(0.2591)
# tensor(0.2861)
# tensor(0.2432)
# tensor(0.2557)
# tensor(0.2330)
# tensor(0.2765)
# tensor(0.2780)
# tensor(0.2856)
# tensor(0.2572)
# tensor(0.2566)
# tensor(0.2640)
# tensor(0.2440)
# tensor(0.2381)
# tensor(0.2457)
# tensor(0.2799)
# tensor(0.2595)
# tensor(0.2661)
# tensor(0.2607)
# tensor(0.2384)
# tensor(0.2583)
# tensor(0.2746)
# tensor(0.2609)
# tensor(0.2612)
# tensor(0.2427)
# tensor(0.2571)
# tensor(0.2772)
# tensor(0.2716)
# tensor(0.2815)
# tensor(0.2534)
# tensor(0.2523)
# tensor(0.2661)
# tensor(0.2430)
# tensor(0.2485)
# tensor(0.2477)
# tensor(0.2753)
# tensor(0.2779)
# tensor(0.2698)
# tensor(0.2381)
# tensor(0.2535)
# tensor(0.2504)
# tensor(0.2518)
# tensor(0.2290)
# tensor(0.2452)
# tensor(0.2383)
# tensor(0.2479)
# tensor(0.2709)
# tensor(0.2755)
# tensor(0.2708)
# tensor(0.2703)
# tensor(0.2316)
# tensor(0.2562)
# tensor(0.2356)
# tensor(0.2512)
# tensor(0.2698)
# tensor(0.2465)
# tensor(0.2313)
# tensor(0.2441)
# tensor(0.2507)
# tensor(0.2440)
# tensor(0.2921)
# tensor(0.2546)
# tensor(0.2465)
# tensor(0.2678)
# tensor(0.2175)
# tensor(0.2420)
# tensor(0.2190)
# tensor(0.2821)
# tensor(0.2496)
# tensor(0.2588)
# tensor(0.2426)
# tensor(0.2386)
# tensor(0.2492)
# tensor(0.2542)
# tensor(0.2692)
# tensor(0.2638)
# tensor(0.2554)
# tensor(0.2463)
# tensor(0.2518)
# tensor(0.2673)
# tensor(0.2527)
# tensor(0.2461)
# tensor(0.2545)
# tensor(0.2311)
# tensor(0.2419)
# tensor(0.2722)
# tensor(0.2421)
# tensor(0.2279)
# tensor(0.2513)
# tensor(0.2478)
# tensor(0.2470)
# tensor(0.2299)
# tensor(0.2461)
# tensor(0.2541)
# tensor(0.2355)
# tensor(0.2230)
# tensor(0.2222)
# tensor(0.2315)
# tensor(0.2437)
# tensor(0.2445)
# tensor(0.2332)
# tensor(0.2460)
# tensor(0.2436)
# tensor(0.2298)
# tensor(0.2485)
# tensor(0.2460)
# tensor(0.2119)
# tensor(0.2499)
# tensor(0.2346)
# tensor(0.2389)
# tensor(0.2555)
# tensor(0.2444)
# tensor(0.2400)
# tensor(0.2443)
# tensor(0.2360)
# tensor(0.2165)
# tensor(0.2454)
# tensor(0.2383)
# tensor(0.2185)
# tensor(0.2327)
# tensor(0.2625)
# tensor(0.2567)
# tensor(0.2344)
# tensor(0.2304)
# tensor(0.2293)
# tensor(0.2511)
# tensor(0.1944)
# tensor(0.2459)
# tensor(0.2036)
# tensor(0.2374)
# tensor(0.2427)
# tensor(0.2334)
# tensor(0.2410)
# tensor(0.2416)
# tensor(0.2495)
# tensor(0.2232)
# tensor(0.2227)
# tensor(0.2503)
# tensor(0.2326)
# tensor(0.2457)
# tensor(0.2262)
# tensor(0.2335)
# tensor(0.2339)
# tensor(0.2232)
# tensor(0.1975)
# tensor(0.2159)
# tensor(0.2082)
# tensor(0.2180)
# tensor(0.2133)
# tensor(0.2294)
# tensor(0.2244)
# tensor(0.2329)
# tensor(0.2080)
# tensor(0.2415)
# tensor(0.2235)
# tensor(0.2181)
# tensor(0.2223)
# tensor(0.2336)
# tensor(0.2499)
# tensor(0.2235)
# tensor(0.2243)
# tensor(0.2190)
# tensor(0.2282)
# tensor(0.2308)
# tensor(0.2020)
# tensor(0.2552)
# tensor(0.2186)
# tensor(0.2260)
# tensor(0.2366)
# tensor(0.2335)
# tensor(0.2222)
# tensor(0.2154)
# tensor(0.2159)
# tensor(0.2245)
# tensor(0.2296)
# tensor(0.2459)
# tensor(0.2179)
# tensor(0.2153)
# tensor(0.2283)
# tensor(0.2140)
# tensor(0.2188)
# tensor(0.2310)
# tensor(0.2270)
# tensor(0.2092)
# tensor(0.2219)
# tensor(0.2199)
# tensor(0.2172)
# tensor(0.2076)
# tensor(0.2215)
# tensor(0.2360)
# tensor(0.2452)
# tensor(0.2287)
# tensor(0.2155)
# tensor(0.2126)
# tensor(0.2036)
# tensor(0.2082)
# tensor(0.2228)
# tensor(0.2195)
# tensor(0.2362)
# tensor(0.2079)
# tensor(0.2063)
# tensor(0.2263)
# tensor(0.2234)
# tensor(0.2238)
# tensor(0.2298)
# tensor(0.2227)
# tensor(0.2341)
# tensor(0.2168)
# tensor(0.2024)
# tensor(0.1985)
# tensor(0.2209)
# tensor(0.2249)
# tensor(0.1969)
# tensor(0.2237)
# tensor(0.2093)
# tensor(0.2225)
# tensor(0.2235)
# tensor(0.2091)
# tensor(0.2207)
# tensor(0.2229)
# tensor(0.2429)
# tensor(0.2372)
# tensor(0.2138)
# tensor(0.2201)
# tensor(0.2091)
# tensor(0.2168)
# tensor(0.2395)
# tensor(0.2410)
# tensor(0.2116)
# tensor(0.2232)
# tensor(0.2219)
# tensor(0.2097)
# tensor(0.2093)
# tensor(0.2227)
# tensor(0.2162)
# tensor(0.2196)
# tensor(0.2101)
# tensor(0.2079)
# tensor(0.2049)
# tensor(0.2161)
# tensor(0.2148)
# tensor(0.2138)
# tensor(0.2165)
# tensor(0.2052)
# tensor(0.2150)
# tensor(0.2116)
# tensor(0.2376)
# tensor(0.2172)
# tensor(0.1794)
# tensor(0.2050)
# tensor(0.2276)
# tensor(0.2170)
# tensor(0.1991)
# tensor(0.2079)
# tensor(0.2139)
# tensor(0.2022)
# tensor(0.1974)
# tensor(0.2161)
# tensor(0.2237)
# tensor(0.2267)
# tensor(0.2066)
# tensor(0.2082)
# tensor(0.2078)
# tensor(0.2090)
# tensor(0.2148)
# tensor(0.2007)
# tensor(0.2063)
# tensor(0.2140)
# tensor(0.2125)
# tensor(0.1922)
# tensor(0.2081)
# tensor(0.2037)
# tensor(0.2035)
# tensor(0.1944)
# tensor(0.2175)
# tensor(0.1988)
# tensor(0.2136)
# tensor(0.1953)
# tensor(0.2160)
# tensor(0.2150)
# tensor(0.2125)
# tensor(0.1995)
# tensor(0.2021)
# tensor(0.2015)
# tensor(0.1962)
# tensor(0.2012)
# tensor(0.2102)
# tensor(0.2206)
# tensor(0.2070)
# tensor(0.2157)
# tensor(0.1934)
# tensor(0.1869)
# tensor(0.2031)
# tensor(0.2024)
# tensor(0.2011)
# tensor(0.2063)
# tensor(0.2057)
# tensor(0.1990)
# tensor(0.2154)
# tensor(0.2102)
# tensor(0.2226)
# tensor(0.2042)
# tensor(0.1989)
# tensor(0.2035)
# tensor(0.1927)
# tensor(0.1866)
# tensor(0.1943)
# tensor(0.2142)
# tensor(0.2022)
# tensor(0.1919)
# tensor(0.2182)
# tensor(0.1935)
# tensor(0.1849)
# tensor(0.2014)
# tensor(0.2096)
# tensor(0.1979)
# tensor(0.1969)
# tensor(0.2011)
# tensor(0.2088)
# tensor(0.2042)
# tensor(0.1977)
# tensor(0.1998)
# tensor(0.1884)
# tensor(0.1995)
# tensor(0.2033)
# tensor(0.2001)
# tensor(0.2052)
# tensor(0.1941)
# tensor(0.1795)
# tensor(0.1896)
# tensor(0.1761)
# tensor(0.1841)
# tensor(0.1977)
# tensor(0.1975)
# tensor(0.2009)
# tensor(0.1868)
# tensor(0.1954)
# tensor(0.1918)
# tensor(0.1782)
# tensor(0.1968)
# tensor(0.1987)
# tensor(0.2034)
# tensor(0.1954)
# tensor(0.2119)
# tensor(0.1935)
# tensor(0.2060)
# tensor(0.1959)
# tensor(0.1958)
# tensor(0.1959)
# tensor(0.1911)
# tensor(0.1949)
# tensor(0.2025)
# tensor(0.1978)
# tensor(0.2048)
# tensor(0.2099)
# tensor(0.2092)
# tensor(0.2101)
# tensor(0.2131)
# tensor(0.1926)
# tensor(0.1927)
# tensor(0.2049)
# tensor(0.2071)
# tensor(0.2021)
# tensor(0.2103)
# tensor(0.2000)
# tensor(0.1921)
# tensor(0.1957)
# tensor(0.2016)
# tensor(0.2047)
# tensor(0.1989)
# tensor(0.2058)
# tensor(0.2014)
# tensor(0.1944)
# tensor(0.1862)
# tensor(0.2035)
# tensor(0.1970)
# tensor(0.1938)
# tensor(0.2089)
# tensor(0.2065)
# tensor(0.2008)
# tensor(0.2143)
# tensor(0.2096)
# tensor(0.2048)
# tensor(0.2085)
# tensor(0.2050)
# tensor(0.1989)
# tensor(0.2027)
# tensor(0.2036)
# tensor(0.2043)
# tensor(0.2044)
# tensor(0.2127)
# tensor(0.2090)
# tensor(0.1949)
# tensor(0.2086)
# tensor(0.2117)
# tensor(0.1981)
# tensor(0.2090)
# tensor(0.2036)
# tensor(0.2096)
# tensor(0.2165)
# tensor(0.2070)
# tensor(0.2116)
# tensor(0.2137)
# tensor(0.2055)
# tensor(0.2045)
# tensor(0.2051)
# tensor(0.2265)
# tensor(0.2206)
# tensor(0.2128)
# tensor(0.2040)
# tensor(0.2139)
# tensor(0.2054)
# tensor(0.2183)
# tensor(0.2117)
# tensor(0.2324)
# tensor(0.2047)
# tensor(0.2219)
# tensor(0.2229)
# tensor(0.2111)
# tensor(0.2327)
# tensor(0.2195)
# tensor(0.2196)
# tensor(0.2284)
# tensor(0.2229)
# tensor(0.2285)
# tensor(0.2136)
# tensor(0.2122)
# tensor(0.2132)
# tensor(0.2230)
# tensor(0.2292)
# tensor(0.2325)
# tensor(0.2303)
# tensor(0.2347)
# tensor(0.2269)
# tensor(0.2281)
# tensor(0.2337)
# tensor(0.2135)
# tensor(0.2320)
# tensor(0.2341)
# tensor(0.2416)
# tensor(0.2423)
# tensor(0.2378)
# tensor(0.2364)
# tensor(0.2366)
# tensor(0.2466)
# tensor(0.2418)
# tensor(0.2442)
# tensor(0.2325)
# tensor(0.2372)
# tensor(0.2370)
# tensor(0.2411)
# tensor(0.2501)
# tensor(0.2324)
# tensor(0.2413)
# tensor(0.2415)
# tensor(0.2433)
# tensor(0.2414)
# tensor(0.2534)
# tensor(0.2518)
# tensor(0.2490)
# tensor(0.2459)
# tensor(0.2553)
# tensor(0.2496)
# tensor(0.2531)
# tensor(0.2590)
# tensor(0.2656)
# tensor(0.2540)
# tensor(0.2557)
# tensor(0.2659)
# tensor(0.2631)
# tensor(0.2610)
# tensor(0.2757)
# tensor(0.2673)
# tensor(0.2575)
# tensor(0.2721)
# tensor(0.2753)
# tensor(0.2787)
# tensor(0.2772)
# tensor(0.2904)
# tensor(0.2892)
# tensor(0.2762)
# tensor(0.2834)
# tensor(0.2841)
# tensor(0.2775)
# tensor(0.2934)
# tensor(0.2790)
# tensor(0.2938)
# tensor(0.2928)
# tensor(0.2969)
# tensor(0.3026)
# tensor(0.2962)
# tensor(0.3001)
# tensor(0.3002)
# tensor(0.3019)
# tensor(0.3079)
# tensor(0.3141)
# tensor(0.3075)
# tensor(0.3089)
# tensor(0.3272)
# tensor(0.3299)
# tensor(0.3237)
# tensor(0.3224)
# tensor(0.3352)
# tensor(0.3320)
# tensor(0.3401)
# tensor(0.3392)
# tensor(0.3386)
# tensor(0.3316)
# tensor(0.3505)
# tensor(0.3546)
# tensor(0.3555)
# tensor(0.3602)
# tensor(0.3937)
# tensor(0.3943)
# tensor(0.4207)
# tensor(0.4279)
# tensor(0.4379)
# tensor(0.4489)
# tensor(0.4966)
# tensor(0.5320)
# tensor(0.5372)
# tensor(0.5684)

# %%
plt.scatter(*est_samples[-1].T.detach().cpu())
