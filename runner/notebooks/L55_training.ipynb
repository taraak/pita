# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import torch
import numpy as np
from torch.optim import Adam
from torch.utils.data import TensorDataset, DataLoader
from fab.utils.logging import ListLogger
from fab.target_distributions.gmm import GMM
from fab.utils.prioritised_replay_buffer import SimpleBuffer
from torch.autograd import grad
from tqdm import tqdm


from typing import Union
import numpy as np
import matplotlib.pyplot as plt
import torch

from typing import Tuple, Optional
import torch
from functorch import vmap


from functools import partial


import torchsde
import matplotlib.pyplot as plt
import numpy as np
from typing import Callable

from math import sqrt


from torchdiffeq import odeint
from torch.func import jacrev

from src.utils.data_utils import remove_mean
from src.models.components.egnn import EGNN_dynamics

from bgflow import Energy
from bgflow.utils import distance_vectors, distances_from_vectors

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ### Target Distribution

# %%
def set_up_tareget(n_particles):
    if n_particles == 55:
        from src.energies.lennardjones_energy import LennardJonesEnergy
        target = LennardJonesEnergy(
            dimensionality=165,
            n_particles=55,
            device=device,
            data_path = "../../data/test_split_LJ55-1000-part1.npy",
            data_path_train= "../../data/train_split_LJ55-1000-part1.npy",
            data_path_val = "../../data/val_split_LJ55-1000-part1.npy",
        )
    elif n_particles == 13:
        from src.energies.lennardjones_energy_eacf import LennardJonesEnergy
        target = LennardJonesEnergy(
            dimensionality=39,
            n_particles=13,
            device=device,
            data_path="../../data/all_data_LJ13.npy",
        )
    return target

# %% [markdown]
# ### Helper Functions

# %%
def clip(f, max_norm):
    norm = torch.linalg.vector_norm(f, dim=-1)
    clip_coef = torch.clamp(max_norm / (norm + 1e-6), max=1)
    f = f * clip_coef.unsqueeze(-1)
    return f

# %%
def sample_from_array(array, size):
    idx = np.random.choice(array.shape[0], size=size)
    return array[idx]

# %% [markdown]
# ## Function Definitions

# %% [markdown]
# ### Estimated Reward Functions

# %%
# calculate the log expectation of the reward
def log_E_R(_x, _t, noise_schedule, num_mc_samples, var_exploding=True):
    repeated_x = _x.unsqueeze(0).repeat_interleave(num_mc_samples, dim=0)
    repeated_t = _t.unsqueeze(0).repeat_interleave(num_mc_samples, dim=0)
    h_t = noise_schedule.h(repeated_t)
    h_t = h_t.unsqueeze(1)
    if var_exploding:
        # variance exploding
        samples = repeated_x + torch.randn(repeated_x.shape).to(device) * (h_t**0.5)
        log_rewards = target(samples).squeeze()
        log_expectation_R = torch.logsumexp(log_rewards, dim=-1) - np.log(
            num_mc_samples
        )
    else:
        # variance preserving
        samples = repeated_x / torch.sqrt(1 - repeated_t.unsqueeze(1)) + torch.randn(
            repeated_x.shape
        ).to(device) * (h_t**0.5)
        log_rewards = target._log_prob(samples).squeeze()
        log_expectation_R = (
            torch.log(1 / (1 - _t))
            + torch.logsumexp(log_rewards, dim=-1)
            - np.log(num_mc_samples)
        )
    return log_expectation_R

# %%
def estimated_Rt(x, t, beta, num_mc_samples=100, var_exploding=True):
    if t.dim() == 0:
        # repeat the same time for all points if we have a scalar time
        t = t * torch.ones(x.shape[0]).to(device)
    return torch.vmap(log_E_R, randomness="different", in_dims=(0, 0, None, None))(
        x, t, beta, num_mc_samples, var_exploding=var_exploding
    )

# %%
def estimate_grad_Rt(
    x, t, noise_schedule, num_mc_samples=100, var_exploding=True, richardson=False
):
    est_scores_n = torch.func.grad(log_E_R)(
        x, t, noise_schedule, num_mc_samples, var_exploding=var_exploding
    )
    if richardson:
        est_scores_n_div2 = torch.func.grad(log_E_R)(
            x, t, noise_schedule, num_mc_samples // 2, var_exploding=var_exploding
        )
        return 2 * est_scores_n - est_scores_n_div2
    else:
        return est_scores_n

# %% [markdown]
# ## SDE

# %% [markdown]
# ### Dataset

# %%
n_nodes = 165
dim = 55

# %%
# test_data = target.sample_test_set(1000)
# dist_test = target.interatomic_dist(test_data)

# %%
# test_data.requires_grad = True
# log_rewards = target(test_data)
# plt.plot(torch.linalg.norm(torch.autograd.grad(log_rewards.sum(), test_data, retain_graph=True)[0], dim=-1).detach().cpu())

# %%
# plt.hist(
#     dist_test.view(-1).cpu(),
#     bins=100,
#     label="holdout samples",
#     alpha=0.5,
#     density=True,
#     histtype="step",
#     linewidth=4,
# )
# plt.show()

# %% [markdown]
# ### VE SDE

# %%
from src.models.components.sdes import VEReverseSDE
from src.models.components.sde_integration import integrate_sde

# %%
# class VEReverseSDE(torch.nn.Module):

#     def __init__(self, score, noise_schedule):
#         super().__init__()
#         self.score = score
#         self.noise_schedule = noise_schedule

#     def f(self, t, x):
#         if t.dim() == 0:
#             # repeat the same time for all points if we have a scalar time
#             t = t * torch.ones(x.shape[0]).to(device)

#         x.requires_grad = True
#         score = self.score(t, x)
#         norm = torch.linalg.vector_norm(score, dim=-1)
#         max_norm = 200
#         clip_coef = torch.clamp(max_norm / (norm+1e-6), max=1)
#         return self.g(t, x)**2 * score * clip_coef[:,None]

#     def g(self, t, x):
#         g = self.noise_schedule.g(t)
#         return g.unsqueeze(1) if g.ndim > 0 else torch.full_like(x, g)

# %%
def generate_samples(reverse_sde, num_samples, return_full_trajectory):
    samples = prior.sample(num_samples)

    return integrate(
        reverse_sde=reverse_sde,
        samples=samples,
        return_full_trajectory=return_full_trajectory,
    )


def integrate(reverse_sde, samples, return_full_trajectory=False):
    trajectory = integrate_sde(
        reverse_sde, samples, 1000 + 1, reverse_time=True, diffusion_scale=0.1
    )
    if return_full_trajectory:
        return trajectory
    return trajectory[-1]

# %% [markdown]
# ### SDE Tests

# %%
from math import log


class VEReverseSDE(torch.nn.Module):
    noise_type = "diagonal"
    sde_type = "ito"

    def __init__(self, score, noise_schedule):
        super().__init__()
        self.score = score
        self.noise_schedule = noise_schedule

    def f(self, t, x):
        if t.dim() == 0:
            # repeat the same time for all points if we have a scalar time
            t = t * torch.ones(x.shape[0]).to(device)

        x.requires_grad = True        

        # with torch.enable_grad():
        #     log_R = target(x)
        #     score = torch.autograd.grad(log_R.sum(), x, retain_graph=True)[0]
            # score = clip(score, 1)
        score = torch.vmap(self.score, randomness="different", in_dims=(0, 0, None))(
            x, 1 - t, self.noise_schedule
        )

        max_norm = 20
        score = score.reshape(-1, 55, 3)
        norm = torch.linalg.norm(score, dim=-1)
        clip_coef = torch.clamp(max_norm / (norm + 1e-6), max=1)
        score= score * clip_coef.unsqueeze(-1)
        score = score.reshape(-1, 165)
        
        # print(torch.linalg.norm(score, dim=-1).mean())
        return self.g(t) ** 2 * score

    def g(self, t):
        return self.noise_schedule.g(1 - t.unsqueeze(1))

# %%
def euler_maruyama_step(sde, x, t, dt):
    # Calculate drift and diffusion terms
    if t.dim() == 0:
        # repeat the same time for all points if we have a scalar time
        t = t * torch.ones(x.shape[0]).to(device)

    drift = sde.f(t, x) * dt
    diffusion = 0.7 * sde.g(t) * np.sqrt(dt) * torch.randn_like(x).to(device) #* np.sqrt(2)

    # Update the state
    x_next = x + drift + diffusion
    return x_next, drift


def integrate_sde(sde, x0, t_span, dt):
    times = torch.arange(t_span[0], t_span[1], dt).to(device)
    x = x0
    x0.requires_grad = True
    vectors = []
    samples = []
    with torch.no_grad():
        for t in times:
            x, f = euler_maruyama_step(sde, x, t, dt)
            samples.append(x)
            vectors.append(f)
    return torch.stack(samples)

# %%
from src.models.components.noise_schedules import (
    LinearNoiseSchedule,
    SubLinearNoiseSchedule,
    GeometricNoiseSchedule,
)
from src.energies.base_prior import MeanFreePrior

# %%
n_particles = 55
target = set_up_tareget(n_particles)

# %%
test_data = target.sample_test_set(1000)
dist_test = target.interatomic_dist(test_data)

# %%
sigma = 5 # np.sqrt(1.5)
beta = torch.tensor(sigma**2)
dim = 3
n_samples = 512

noise_schedule = GeometricNoiseSchedule(0.001, sigma)
#noise_schedule = LinearNoiseSchedule(beta)

prior = MeanFreePrior(n_particles, 3, noise_schedule.h(1) ** 0.5, device=device)
print(noise_schedule.h(1))
x1_samples = prior.sample(n_samples).to(device)
# Out:
# 24.999999

# %%
x1_samples_dists = target.interatomic_dist(x1_samples)
filter = (x1_samples_dists > 0.8).all(-1)

x1_samples = x1_samples[filter]

x1_samples.shape
# Out:
# torch.Size([296, 165])

# %%
t = torch.linspace(0, 1, 1000).to(device)
g = noise_schedule.g(t)
h = noise_schedule.h(t)
plt.plot(t.cpu(), g.cpu())

# %%
ve_reverse_sde = VEReverseSDE(estimate_grad_Rt, noise_schedule)
samples_pred = integrate_sde(ve_reverse_sde, x1_samples, [0, 1], 1e-3)

# %%
target(x1_samples).mean()
# Out:
# tensor(-8.5643e+09, device='cuda:0', grad_fn=<MeanBackward0>)

# %%
samples_mean_free = (samples_pred[-1].reshape(-1, n_particles, dim) - samples_pred[-1].reshape(-1, n_particles, dim).mean(1, keepdim=True))

# %%
plt.scatter(test_data[:10].reshape(-1, 3)[:, 0].detach().cpu(), test_data[:10].reshape(-1, 3)[:, 1].detach().cpu(), alpha=0.3)

#plt.scatter(x1_samples[:10].reshape(-1, 3)[:, 0].detach().cpu(), x1_samples[:10].reshape(-1, 3)[:, 1].detach().cpu(), alpha=0.3)


# plt.scatter(samples_mean_free.reshape(-1, 3)[:, 0].detach().cpu(), samples_mean_free.reshape(-1, 3)[:, 1].detach().cpu(), alpha=0.1)
plt.scatter(samples_pred[-1].reshape(-1, 3)[:, 0].detach().cpu(), samples_pred[-1].reshape(-1, 3)[:, 1].detach().cpu(), alpha=0.1)



lim = 5
plt.xlim(-lim, lim)
plt.ylim(-lim, lim)
# Out:
# (-5.0, 5.0)

# %%
def calculate_variance(x0):
    times = torch.linspace(0, 1, 100, device=device)
    f_xt = []
    eps = torch.randn_like(x0)
    num_replicates = 32

    for t in times:
        h_t = noise_schedule.h(t).unsqueeze(0)
        # noisy sample: x(t)
        x_t = (x0 + sqrt(h_t) * eps).repeat(num_replicates, 1)
        v_t = torch.vmap(estimate_grad_Rt, in_dims=(0, None, None), randomness="different")(
            x_t, t, noise_schedule, num_mc_samples=100)
        f_xt.append(v_t
        )
    f_xt = torch.stack(f_xt, dim=0)
    return f_xt

# %%
# num_points = 10
# x0 = target.sample_test_set(num_points)
# f_xt_all = torch.vmap(calculate_variance, in_dims=(0,), randomness="different")(x0)

# %%
# vars_9 = []
# for i in range(0, num_points):
#     f_xt = f_xt_all[i]
#     cov = torch.vmap(torch.cov)(f_xt.permute(0, 2, 1))
#     var = torch.vmap(torch.trace)(cov).detach()
#     vars_9.append(var[-2])

#     times = torch.linspace(0, 1, 100, device=device)
#     plt.plot(times.cpu(), var.cpu())
#     plt.xlabel("time")
#     plt.ylabel("variance")
# vars_9 = torch.stack(vars_9).cpu()

# %%
# from src.energies.lennardjones_energy_eacf import LennardJonesEnergy

# # target = LennardJonesEnergy(
# #     dimensionality=39,
# #     n_particles=13,
# #     device=device,
# #     data_path="../../data/all_data_LJ13.npy",
# # )



# from src.energies.lennardjones_energy import LennardJonesEnergy

# target = LennardJonesEnergy(
#     dimensionality=165,
#     n_particles=55,
#     device=device,
#     data_path = "../../data/test_split_LJ55-1000-part1.npy",
#     data_path_train= "../../data/train_split_LJ55-1000-part1.npy",
#     data_path_val = "../../data/val_split_LJ55-1000-part1.npy",
# )

# sigma = 1  # np.sqrt(1.5)
# beta = torch.tensor(sigma**2)
# dim = 3
# n_nodes = 13
# n_samples = 512  # 512

# #noise_schedule = GeometricNoiseSchedule(0.001, sigma)
# noise_schedule = LinearNoiseSchedule(beta)

# prior = MeanFreePrior(55, 3, noise_schedule.h(1) ** 0.5, device=device)
# print(noise_schedule.h(1))
# x1_samples = prior.sample(n_samples).to(device)

# %%
# x1_samples = test_data / 10 #+ torch.randn_like(test_data) * 0.1

# %%
from bgflow.utils import distance_vectors, distances_from_vectors

# %%
r =  distances_from_vectors(distance_vectors(test_data.view(-1, 55, 3)))

# %%
((1 / 0.8) ** 12 - 2 * (1 / 0.8) ** 6)
# Out:
# 6.922520697116852

# %%
def energy(r):
    p = 0.9
    lj = 1 * ((1 / r) ** 12 - 2 * (1 / r) ** 6)
    filter = (r < p)
    lj[filter] =  energy_slope(p) * (r[filter]-p) +  ((1 / p) ** 12 - 2 * (1 / p) ** 6)
    return lj


def energy_slope(r):
    return 12 * (r**6 - 1)/r**13

# %%
r = torch.linspace(0.1, 10, 1000)

# %%
r.requires_grad = True
slope_e_r = torch.autograd.grad(energy(r).sum(), r)[0].detach().cpu()

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 5))
axs[0].plot(r.detach().cpu(), slope_e_r)


energy_r= energy(r).detach().cpu()
axs[1].plot(r.detach().cpu(), energy_r)

# %%
# r.requires_grad = True
# slope_energy = torch.autograd.grad(energy(r).sum(), r)[0]

# %%
#plt.plot(r.detach().cpu(), slope_energy.detach().cpu())

# %%
lj.shape
# Out:
# torch.Size([1000, 55, 54])

# %%
samples_energy = target(samples_pred[-1])
test_data_energy = target(test_data)

# %%
target.interatomic_dist(test_data)
# Out:
# tensor([[0.9430, 2.3626, 3.1785,  ..., 1.7199, 2.3375, 1.0247],
#         [3.6398, 4.0832, 3.1964,  ..., 2.9426, 2.9429, 0.9617],
#         [2.0109, 1.8077, 2.9693,  ..., 1.2932, 2.7348, 1.7973],
#         ...,
#         [1.0467, 2.4945, 2.9443,  ..., 3.0240, 3.5260, 1.4696],
#         [2.1752, 2.8414, 3.5447,  ..., 1.1012, 1.9373, 1.8769],
#         [1.7517, 1.9855, 2.8708,  ..., 2.3331, 2.4961, 3.4801]],
#        device='cuda:0')

# %%
plt.hist(-test_data_energy.detach().cpu(), bins=100, density=True, alpha=0.4,
    color="g", histtype='step', linewidth=4, label="test data");

plt.show()
plt.hist(-target(samples_pred[-1]).detach().cpu(), bins=100, density=True, alpha=0.4,
    color="g", histtype='step', linewidth=4, label="test data");
plt.show()


# plt.hist(-target(x1_samples).detach().cpu(), bins=100, density=True, alpha=0.4,
#     color="g", histtype='step', linewidth=4, label="test data");
# plt.show()

# %%
samples_to_plot = range(0, 100, 9)
colors = plt.cm.viridis(np.linspace(0, 1, len(samples_to_plot)))
color_gradient = plt.colormaps["PuRd"].resampled(12)

# %%
pred_dists = []
for t in range(0, 100, 9):
    pred_dists.append(target.interatomic_dist(samples_pred[t]).detach())
pred_dists = torch.stack(pred_dists)

# %%
# fig = plt.figure(figsize=(8, 8))
# for dist in pred_dists[-1:]:
#     plt.hist(
#         dist.view(-1).cpu().numpy(),
#         bins=200,
#         density=True,
#         histtype="step",
#         linewidth=4,
#         alpha=0.4,
#     )
plt.hist(
    target.interatomic_dist(samples_pred[-1]).detach().view(-1).cpu().numpy(),
    bins=200,
    density=True,
    histtype="step",
    linewidth=4,
    alpha=0.4,
)
plt.hist(
    target.interatomic_dist(samples_pred[0]).detach().view(-1).cpu().numpy(),
    bins=200,
    density=True,
    histtype="step",
    linewidth=4,
    alpha=0.4,
)
plt.hist(
    dist_test.view(-1).cpu(),
    bins=100,
    color="r",
    alpha=0.5,
    density=True,
    histtype="step",
    linewidth=4,
)
plt.xlim(0, 10)
# plt.ylim(0, 2)
plt.show()

# %%
plt.hist(
    -test_data_energy.detach().cpu(),
    bins=100,
    density=True,
    alpha=0.4,
    range=(-380, 200),
    color="g",
    histtype="step",
    linewidth=4,
    label="test data",
)

plt.hist(
    -samples_energy.detach().cpu(),
    bins=100,
    density=True,
    alpha=0.4,
    range=(-380, 200),
    color="r",
    histtype="step",
    linewidth=4,
    label="generated data",
)
plt.xlabel("Energy")
plt.legend()
plt.show()

# %% [markdown]
# ## Training

# %% [markdown]
# ### Dataset

# %%
from src.models.components.noise_schedules import LinearNoiseSchedule

# %%
sigma = np.sqrt(1.5)
beta = torch.tensor(sigma**2)
dim = 3
n_nodes = 13
n_samples = 1000  # 512

noise_schedule = LinearNoiseSchedule(beta)

# %%
from src.energies.base_prior import MeanFreePrior

# %%
prior = MeanFreePrior(13, 3, sigma, device=device)
x1_samples = prior.sample(n_samples).to(device)
x1_energy = prior.log_prob(x1_samples)

x1_dists = target.interatomic_dist(x1_samples)
plt.hist(
    x1_dists.view(-1).cpu().numpy(),
    bins=100,
    alpha=0.5,
    density=True,
    histtype="step",
    linewidth=4,
)
plt.show()

# %% [markdown]
# ### Model

# %%
# class VEReverseSDE(torch.nn.Module):

#     def __init__(self, score, noise_schedule):
#         super().__init__()
#         self.score = score
#         self.noise_schedule = noise_schedule

#     def f(self, t, x):
#         with torch.enable_grad():
#             if t.dim() == 0:/
#                 # repeat the same time for all points if we have a scalar time
#                 t = t * torch.ones(x.shape[0]).to(x.device)

#             x.requires_grad = True
#             score = self.score(t, x)

#         return self.g(t, x).pow(2) * score

#     def g(self, t, x):
#         g = self.noise_schedule.g(t)
#         return g.unsqueeze(1) if g.ndim > 0 else torch.full_like(x, g)

# %%
# class VEReverseSDE(torch.nn.Module):

#     def __init__(self, score, noise_schedule):
#         super().__init__()
#         self.score = score
#         self.noise_schedule = noise_schedule

#     def f(self, t, x):
#         if t.dim() == 0:
#             # repeat the same time for all points if we have a scalar time
#             t = t * torch.ones(x.shape[0]).to(device)

#         x.requires_grad = True
#         score = self.score((1-t), x)
#         return self.g(t, x)**2 * score

#     def g(self, t, x):
#         return self.noise_schedule.g(1-t.unsqueeze(1))

# %%
# def euler_maruyama_step(sde, x, t, dt):
#     # Calculate drift and diffusion terms
#     if t.dim() == 0:
#         # repeat the same time for all points if we have a scalar time
#         t = t * torch.ones(x.shape[0]).to(device)

#     drift = sde.f(t, x) * dt
#     diffusion = sde.g(t, x) * 0.1 * np.sqrt(dt) * torch.randn_like(x).to(device)

#     # Update the state
#     x_next = x + drift + diffusion
#     return x_next, drift

# def integrate_sde(sde, x0, t_span, dt):
#     times = torch.arange(t_span[0], t_span[1], dt).to(device)
#     x = x0
#     x0.requires_grad = True
#     vectors = []
#     samples = []
#     with torch.no_grad():
#         for t in times:
#             x, f = euler_maruyama_step(sde, x, t, dt)
#             samples.append(x)
#             vectors.append(f)
#     return torch.stack(samples)

# %% [markdown]
# ### Training

# %%
def reward_matching_loss_biased(vectorfield, x, t, noise_schedule, weighted=False):
    h_t = noise_schedule.h(t.unsqueeze(1))

    x.requires_grad = True

    # noisy sample: x(t)
    noisy_x = torch.normal(x, h_t**0.5)
    pred_scores = vectorfield(t, noisy_x)

    estimated_scores = torch.vmap(
        estimate_grad_Rt, in_dims=(0, 0, None), randomness="different"
    )(noisy_x, t, noise_schedule)
    estimated_scores = clip(estimated_scores, max_norm=50)

    if weighted:
        lambda_t = h_t + 1e-3
        err = (
            estimated_scores - pred_scores
        ) ** 2  # torch.linalg.vector_norm((estimated_scores - pred_scores), dim=-1)**2
        return (lambda_t * err).mean()
    else:
        err = (
            estimated_scores - pred_scores
        ) ** 2  # torch.linalg.vector_norm((estimated_scores - pred_scores), dim=-1)**2
        return err.mean()

# %%
from src.models.components.prioritised_replay_buffer import SimpleBuffer

# %%
buffer = SimpleBuffer(
    n_nodes * dim,
    10000,
    1000,
    initial_sampler=None,
    device=device,
    fill_buffer_during_init=False,
    sample_with_replacement=True,
    prioritize=False,
)

buffer.add(x1_samples.reshape(-1, n_nodes * dim), x1_energy)
# Out:
# Buffer not initialised, expected that checkpoint will be loaded.

# %%
outer_epochs = 100
inner_epochs = 100

batch_size = 512

train_dataset = TensorDataset(x1_samples.clone(), x1_energy.clone())
trainloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# %%
vectorfield = EGNN_dynamics(
    n_particles=n_nodes,
    n_dimension=dim,
    hidden_nf=32,
    act_fn=torch.nn.SiLU(),
    n_layers=3,
    recurrent=True,
    tanh=True,
    attention=True,
    condition_time=True,
    agg="sum",
).to(device)

opt_vectorfield = Adam(vectorfield.parameters(), lr=1e-3)
weighted = False

# %%
from src.models.components.clipper import Clipper

# %%
clipper_sde = Clipper(
    should_clip_scores=False, should_clip_log_rewards=True, max_score_norm=100
)

# %%
for epoch in tqdm(range(outer_epochs)):
    for epoch in range(inner_epochs):
        total_loss = 0.0
        for samples, _ in trainloader:
            samples = samples.to(device)
            opt_vectorfield.zero_grad()

            t = torch.rand(len(samples), device=device)

            loss = reward_matching_loss_biased(
                vectorfield, samples, t, noise_schedule, weighted=weighted
            )
            total_loss += loss.item()
            loss.backward()
            opt_vectorfield.step()
        if epoch % 49 == 0:
            print("Epoch %d | Loss %f" % (epoch, loss.item()))

    # Generate samples using the vector field

    # ve_reverse_sde = VEReverseSDE(
    #             clipper_sde.wrap_grad_fxn(vectorfield),
    #             noise_schedule
    #           )

    ve_reverse_sde = VEReverseSDE(vectorfield, noise_schedule)
    samples = generate_samples(ve_reverse_sde, n_samples, return_full_trajectory=False)
    # x1_samples = prior.sample(n_samples)
    # samples = integrate_sde(ve_reverse_sde, x1_samples, [0, 1], 1e-3)[-1]
    samples_energy = target(samples).detach().squeeze()

    # Update Buffer
    buffer.add(samples, samples_energy)

    dist_samples = target.interatomic_dist(samples)

    plt.hist(
        dist_samples.view(-1).detach().cpu().numpy(),
        bins=200,
        alpha=0.5,
        density=True,
        histtype="step",
        linewidth=4,
    )
    plt.hist(
        dist_test.view(-1).detach().cpu().numpy(),
        bins=100,
        alpha=0.5,
        density=True,
        histtype="step",
        linewidth=4,
    )
    plt.show()
    # target.get_dist_hist(samples)

    # Resample data from the buffer
    samples, samples_energy, _ = buffer.sample(512 * 10)
    train_dataset = TensorDataset(samples, samples_energy)
    trainloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | Loss 34.949993
# Epoch 49 | Loss 37.658928
# Epoch 98 | Loss 35.120689
#   1%|          | 1/100 [01:10<1:56:25, 70.56s/it]
# Epoch 0 | Loss 36.067844
# Epoch 49 | Loss 35.442318
# Epoch 98 | Loss 36.970222
#   2%|▏         | 2/100 [02:20<1:54:44, 70.25s/it]
# Epoch 0 | Loss 37.629658
#   2%|▏         | 2/100 [02:39<2:10:14, 79.74s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[100], line 10
#       6 opt_vectorfield.zero_grad()
#       8 t = torch.rand(len(samples), device=device)
# ---> 10 loss = reward_matching_loss_biased(vectorfield, samples, t, noise_schedule, weighted=weighted)
#      11 total_loss += loss.item()
#      12 loss.backward()
#
# Cell In[92], line 10, in reward_matching_loss_biased(vectorfield, x, t, noise_schedule, weighted)
#       7 noisy_x = torch.normal(x, h_t ** 0.5)
#       8 pred_scores = vectorfield(t, noisy_x)
# ---> 10 estimated_scores = torch.vmap(estimate_grad_Rt, in_dims=(0,0,None), randomness="different")(noisy_x, t, noise_schedule)
#      11 estimated_scores = clip(estimated_scores, max_norm=50)
#      13 if weighted:
#
# File ~/.conda/envs/actinfenv/lib/python3.10/site-packages/torch/_functorch/apis.py:188, in vmap.<locals>.wrapped(*args, **kwargs)
#     187 def wrapped(*args, **kwargs):
# --> 188     return vmap_impl(func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs)
#
# File ~/.conda/envs/actinfenv/lib/python3.10/site-packages/torch/_functorch/vmap.py:266, in vmap_impl(func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs)
#     262     return _chunked_vmap(func, flat_in_dims, chunks_flat_args,
#     263                          args_spec, out_dims, randomness, **kwargs)
#     265 # If chunk_size is not specified.
# --> 266 return _flat_vmap(
#     267     func, batch_size, flat_in_dims, flat_args, args_spec, out_dims, randomness, **kwargs
#     268 )
#
# File ~/.conda/envs/actinfenv/lib/python3.10/site-packages/torch/_functorch/vmap.py:38, in doesnt_support_saved_tensors_hooks.<locals>.fn(*args, **kwargs)
#      35 @functools.wraps(f)
#      36 def fn(*args, **kwargs):
#      37     with torch.autograd.graph.disable_saved_tensors_hooks(message):
# ---> 38         return f(*args, **kwargs)
#
# File ~/.conda/envs/actinfenv/lib/python3.10/site-packages/torch/_functorch/vmap.py:379, in _flat_vmap(func, batch_size, flat_in_dims, flat_args, args_spec, out_dims, randomness, **kwargs)
#     377 try:
#     378     batched_inputs = _create_batched_inputs(flat_in_dims, flat_args, vmap_level, args_spec)
# --> 379     batched_outputs = func(*batched_inputs, **kwargs)
#     380     return _unwrap_batched(batched_outputs, out_dims, vmap_level, batch_size, func)
#     381 finally:
#
# Cell In[12], line 2, in estimate_grad_Rt(x, t, noise_schedule, num_mc_samples, var_exploding, richardson)
#       1 def estimate_grad_Rt(x, t, noise_schedule, num_mc_samples=100, var_exploding=True, richardson=False):
# ----> 2     est_scores_n = torch.func.grad(log_E_R)(x, t, noise_schedule, num_mc_samples, var_exploding=var_exploding)
#       3     if richardson:
#       4         est_scores_n_div2 = torch.func.grad(log_E_R)(x, t, noise_schedule, num_mc_samples//2, var_exploding=var_exploding)
#
# File ~/.conda/envs/actinfenv/lib/python3.10/site-packages/torch/_functorch/apis.py:363, in grad.<locals>.wrapper(*args, **kwargs)
#     361 @functools.wraps(func)
#     362 def wrapper(*args, **kwargs):
# --> 363     return eager_transforms.grad_impl(func, argnums, has_aux, args, kwargs)
#
# File ~/.conda/envs/actinfenv/lib/python3.10/site-packages/torch/_functorch/eager_transforms.py:1287, in grad_impl(func, argnums, has_aux, args, kwargs)
#    1285 def grad_impl(func: Callable, argnums: argnums_t, has_aux: bool, args, kwargs):
#    1286     func = lazy_dynamo_disable(func)
# -> 1287     results = grad_and_value(func, argnums, has_aux=has_aux)(*args, **kwargs)
#    1288     if has_aux:
#    1289         grad, (_, aux) = results
#
# File ~/.conda/envs/actinfenv/lib/python3.10/site-packages/torch/_functorch/vmap.py:38, in doesnt_support_saved_tensors_hooks.<locals>.fn(*args, **kwargs)
#      35 @functools.wraps(f)
#      36 def fn(*args, **kwargs):
#      37     with torch.autograd.graph.disable_saved_tensors_hooks(message):
# ---> 38         return f(*args, **kwargs)
#
# File ~/.conda/envs/actinfenv/lib/python3.10/site-packages/torch/_functorch/eager_transforms.py:1248, in grad_and_value.<locals>.wrapper(*args, **kwargs)
#    1245 diff_args = _slice_argnums(args, argnums, as_tuple=False)
#    1246 tree_map_(partial(_create_differentiable, level=level), diff_args)
# -> 1248 output = func(*args, **kwargs)
#    1249 if has_aux:
#    1250     if not (isinstance(output, tuple) and len(output) == 2):
#
# File ~/.conda/envs/actinfenv/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:328, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     326 dynamic_ctx.__enter__()
#     327 try:
# --> 328     return fn(*args, **kwargs)
#     329 finally:
#     330     set_eval_frame(prior)
#
# Cell In[10], line 9, in log_E_R(_x, _t, noise_schedule, num_mc_samples, var_exploding)
#       6 h_t = h_t.unsqueeze(1)
#       7 if var_exploding:
#       8     # variance exploding
# ----> 9     samples = repeated_x + torch.randn(repeated_x.shape).to(device) * (h_t ** 0.5)
#      10     log_rewards = target(samples).squeeze()
#      11     log_expectation_R = torch.logsumexp(log_rewards, dim=
#      12                                         -1) - np.log(num_mc_samples)
#
# KeyboardInterrupt:

# %%
x1_samples = prior.sample(10000).reshape(-1, n_nodes * dim)
ve_reverse_sde = VEReverseSDE(vectorfield, noise_schedule)
samples = integrate_sde(ve_reverse_sde, x1_samples, [0, 1], 1e-3)[-1]


samples_energy = -target._log_prob(samples).detach().squeeze()
test_energy = -target._log_prob(test_data).detach().squeeze()

# %%
data_holdout.shape
# Out:
# torch.Size([500000, 39])

# %%
test_energy.shape
# Out:
# torch.Size([1000])

# %%
min_energy = min(test_energy.min(), samples_energy.min()).cpu().item()
max_energy = max(test_energy.max(), samples_energy.max()).cpu().item()

# %%
plt.hist(
    test_energy.cpu(),
    bins=100,
    density=True,
    alpha=0.4,
    range=(-60, 0),
    color="g",
    histtype="step",
    linewidth=4,
    label="test data",
)

plt.hist(
    samples_energy.cpu(),
    bins=100,
    density=True,
    alpha=0.4,
    range=(-60, 0),
    color="r",
    histtype="step",
    linewidth=4,
    label="generated data",
)
plt.xlabel("Energy")
plt.legend()

# %%
dist_samples = interatomic_dist(samples.reshape(-1, n_nodes, dim))
dist_holdout = interatomic_dist(data_holdout.reshape(-1, n_nodes, dim))
plt.hist(
    dist_samples.view(-1).detach().cpu().numpy(),
    bins=200,
    alpha=0.5,
    density=True,
    histtype="step",
    linewidth=4,
)
plt.hist(
    dist_holdout.view(-1).detach().cpu().numpy(),
    bins=100,
    alpha=0.5,
    density=True,
    histtype="step",
    linewidth=4,
);

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ### NLL

# %%
follow_estimate = False
follow_model = True
reverse_time = False

# %%
def prior_dist(beta):
    dist = torch.distributions.MultivariateNormal(
        torch.zeros(n_nodes * dim).to(device),
        torch.eye(n_nodes * dim).to(device) * beta,
    )
    return dist

# %%
def drift(x, t):
    with torch.enable_grad():
        x.requires_grad = True

        if follow_estimate:
            f = estimate_grad_Rt(x, t, noise_schedule, num_mc_samples=100)
            f = clip(f, max_norm=100)
            f = -0.5 * noise_schedule.g(t) ** 2 * f

        else:
            f = vectorfield(t.unsqueeze(-1), x)
            # f = clip(f, max_norm=100)
            f = -0.5 * noise_schedule.g(t)[0] ** 2 * f

    return f

# %%
def div_fn(u):
    """Accepts a function u:R^D -> R^D."""
    J = jacrev(u)
    if follow_model:

        def div(x):
            return torch.trace(J(x.unsqueeze(0)).squeeze())

        return div
    else:
        return lambda x: torch.trace(J(x))


def output_and_div(vecfield, x):
    if follow_estimate:
        dx = torch.vmap(vecfield, randomness="different")(x)
    else:
        dx = vecfield(x)

    if reverse_time:
        div = torch.zeros((x.shape[0]), device=device)
    else:
        div = torch.vmap(div_fn(vecfield), randomness="different")(x)
    return dx, div

# %%
def odefunc(t, x_in):
    x = x_in[..., :-1].clone().detach().requires_grad_(True)
    t = t.to(device)

    vecfield = lambda x: drift(x, t)
    if follow_model:

        def vecfield(x):
            return drift(x, torch.ones(x.shape[0]).to(device) * t)

    dx, div = output_and_div(vecfield, x)
    div = div.reshape(-1, 1)
    return torch.cat([dx, div], dim=-1)


with torch.no_grad():
    if reverse_time:
        x1 = torch.randn(1024, 39).to(device) * sigma
        time = torch.linspace(1, 0, 1000).to(device)
    else:
        x1 = test_data
        time = torch.linspace(0, 1, 100).to(device)
    state1 = torch.cat([x1, torch.zeros_like(x1[..., :1])], dim=-1)
    state1.requires_grad = True
    state0 = odeint(odefunc, state1, t=time, method="euler")[-1]

    x0, logdetjac = state0[..., :-1], state0[..., -1]
    p0 = prior_dist(beta)
    logp0 = p0.log_prob(x0)
    logp1 = -(logp0 + logdetjac)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 15
#      12     return torch.cat([dx, div], dim=-1)
#      14 with torch.no_grad():
# ---> 15     if reverse_time:
#      16         x1 = torch.randn(1024, 39).to(device) * sigma
#      17         time = torch.linspace(1, 0, 1000).to(device)
#
# NameError: name 'reverse_time' is not defined

# %%
print("logp0", logp0.mean())
print("logdetjac", logdetjac.mean())
print("logp1", logp1.mean())
# Out:
# logp0 tensor(-47.5622, device='cuda:0')
# logdetjac tensor(-15.4821, device='cuda:0')
# logp1 tensor(63.0443, device='cuda:0')

# %%
x0_true = torch.randn((1000, n_nodes * dim), device=device) * np.sqrt(beta)
true_logp0 = p0.log_prob(x0_true.view(-1, 39))
print("true_logp0", true_logp0.mean())
# Out:
# true_logp0 tensor(-63.3848, device='cuda:0')

# %%
x0 = x0.reshape(-1, n_nodes, dim)
x0_dists = interatomic_dist(x0)
x0_true_dists = interatomic_dist(x0_true.reshape(-1, n_nodes, dim)).detach()
test_dists = interatomic_dist(test_data.reshape(-1, n_nodes, dim))

plt.hist(
    x0_dists.view(-1).detach().cpu().numpy(),
    bins=200,
    alpha=0.5,
    density=True,
    histtype="step",
    linewidth=4,
    label="x0",
)
plt.hist(
    x0_true_dists.view(-1).detach().cpu().numpy(),
    bins=200,
    alpha=0.5,
    density=True,
    histtype="step",
    linewidth=4,
    label="true prior",
)
plt.hist(
    test_dists.view(-1).cpu().numpy(),
    bins=200,
    alpha=0.5,
    density=True,
    histtype="step",
    linewidth=4,
    label="true x1",
)
plt.xlim(0.05, 8)
plt.ylim(0, 2.0)
plt.legend()
plt.show()
