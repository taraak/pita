# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
import torch
import numpy as np
from torch.optim import Adam
from torch.utils.data import TensorDataset, DataLoader
from tqdm import tqdm
from src.models.components.mlp import MyMLP

import torch
import torchsde
from torch import vmap
from torchdiffeq import odeint

from src.energies.gmm_energy import GMM
from fab.target_distributions import gmm

from src.energies.base_prior import Prior, MeanFreePrior

from src.models.components.clipper import Clipper

from torch.func import hessian

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ### Target Distribution

# %%
n_particles = 4
spatial_dim = 2
dimensionality = spatial_dim * n_particles

from src.energies.multi_double_well_energy import MultiDoubleWellEnergy
target = MultiDoubleWellEnergy(dimensionality,
                                n_particles=n_particles,
                                data_path="../../data/test_split_DW4.npy",
                                data_path_train="../../data/train_split_DW4.npy", 
                                data_path_val="../../data/val_split_DW4.npy", 
                                device=device)

# %%
a = torch.tensor([[0.9041, 0.0196], [-0.3108, -2.4423], [-0.4821, 1.059]])
b = torch.tensor([[-2.1763, -0.4713], [-0.6986, 1.3702]])
torch.cdist(a, b, p=2)
# Out:
# tensor([[3.1193, 2.0959],
#         [2.7138, 3.8322],
#         [2.2830, 0.3791]])

# %%
diff = a[:, None, :] - b[None, :, :]
torch.norm(diff, dim=-1)
# Out:
# tensor([[3.1193, 2.0959],
#         [2.7138, 3.8322],
#         [2.2830, 0.3791]])

# %%
a = target.sample_test_set(1000)
target.get_dataset_fig(a);
# Out:
# tensor([[4.9913, 2.6973, 3.2858, 4.9871, 2.4620, 2.5339],
#         [5.2182, 2.8866, 5.3328, 2.7326, 2.4761, 2.4799],
#         [5.4268, 5.3175, 2.6117, 2.1378, 4.7408, 5.6655],
#         [2.7559, 3.0376, 4.9530, 4.6737, 5.3005, 2.5888],
#         [2.4893, 2.4590, 4.8717, 2.5727, 5.3673, 2.8308],
#         [5.5050, 5.4604, 2.4262, 5.4530, 3.0788, 4.7202],
#         [2.7090, 5.1270, 2.0060, 5.4472, 2.6951, 3.2171],
#         [3.2394, 5.1988, 2.2980, 2.6359, 2.5442, 5.1562],
#         [2.3176, 5.4462, 2.7624, 5.1577, 2.7129, 2.7211],
#         [4.7201, 5.6096, 2.2139, 2.2115, 5.5382, 5.5452]], device='cuda:0')
# tensor([[4.9913, 2.6973, 3.2858, 4.9871, 2.4620, 2.5339],
#         [5.2182, 2.8866, 5.3328, 2.7326, 2.4761, 2.4799],
#         [5.4268, 5.3175, 2.6117, 2.1378, 4.7408, 5.6655],
#         [2.7559, 3.0376, 4.9530, 4.6737, 5.3005, 2.5888],
#         [2.4893, 2.4590, 4.8717, 2.5727, 5.3673, 2.8308],
#         [5.5050, 5.4604, 2.4262, 5.4530, 3.0788, 4.7202],
#         [2.7090, 5.1270, 2.0060, 5.4472, 2.6951, 3.2171],
#         [3.2394, 5.1988, 2.2980, 2.6359, 2.5442, 5.1562],
#         [2.3176, 5.4462, 2.7624, 5.1577, 2.7129, 2.7211],
#         [4.7201, 5.6096, 2.2139, 2.2115, 5.5382, 5.5452]], device='cuda:0')
# tensor([[3.5069, 5.8719, 2.1950, 2.5067, 2.8113, 5.2816],
#         [4.9506, 2.2756, 2.6911, 5.0297, 2.6375, 2.4086],
#         [5.1490, 2.8991, 2.2147, 2.9268, 5.7276, 2.8239],
#         [3.0226, 2.8257, 2.5071, 2.8261, 2.5519, 4.4161],
#         [2.8851, 5.3092, 2.6464, 3.0709, 2.2635, 2.9695],
#         [5.2736, 5.5116, 5.5295, 2.9773, 2.5618, 5.4583],
#         [2.9195, 2.3988, 2.6543, 5.1561, 5.4160, 2.3780],
#         [3.1367, 2.8282, 5.2036, 3.0758, 2.4929, 5.5518],
#         [5.6804, 5.4969, 2.9227, 5.9809, 2.7584, 5.0455],
#         [2.3273, 5.3347, 2.6926, 3.0346, 2.8301, 5.3078]], device='cuda:0')
# tensor([[3.5069, 5.8719, 2.1950, 2.5067, 2.8113, 5.2816],
#         [4.9506, 2.2756, 2.6911, 5.0297, 2.6375, 2.4086],
#         [5.1490, 2.8991, 2.2147, 2.9268, 5.7276, 2.8239],
#         [3.0226, 2.8257, 2.5071, 2.8261, 2.5519, 4.4161],
#         [2.8851, 5.3092, 2.6464, 3.0709, 2.2635, 2.9695],
#         [5.2736, 5.5116, 5.5295, 2.9773, 2.5618, 5.4583],
#         [2.9195, 2.3988, 2.6543, 5.1561, 5.4160, 2.3780],
#         [3.1367, 2.8282, 5.2036, 3.0758, 2.4929, 5.5518],
#         [5.6804, 5.4969, 2.9227, 5.9809, 2.7584, 5.0455],
#         [2.3273, 5.3347, 2.6926, 3.0346, 2.8301, 5.3078]], device='cuda:0')

# %% [markdown]
# ## Function Definitions

# %%
class VEReverseSDE(torch.nn.Module):
    noise_type = "diagonal"
    sde_type = "ito"

    def __init__(self, score, noise_schedule):
        super().__init__()
        self.score = score
        self.noise_schedule = noise_schedule

    def f(self, t, x):
        if t.dim() == 0:
            # repeat the same time for all points if we have a scalar time
            t = t * torch.ones(x.shape[0]).to(x.device)

        score = self.score(t, x)
        return self.g(t, x).pow(2) * score

    def g(self, t, x):
        g = self.noise_schedule.g(t)
        return g

# %%
def compute_laplacian(model, t, xt):
    
    def func_wrap(t, xt):
        return model(t.unsqueeze(0), xt.unsqueeze(0)).squeeze()
    
    # Calculate the Hessian matrix of the model output with respect to the input
    hessian_matrix = vmap(hessian(func_wrap, argnums=1))(t, xt)

    # Calculate the Laplacian as the trace of the Hessian matrix
    laplacian = hessian_matrix.diagonal(offset=0, dim1=-2, dim2=-1).sum(dim=-1)
    return laplacian

# %%
def rademacher(shape, dtype=torch.float32, device='cuda'):
    """Sample from Rademacher distribution."""
    rand = ((torch.rand(shape) < 0.5)) * 2 - 1
    return rand.to(dtype).to(device)

# %%
def compute_laplacian_hutchinson(nabla_Ut, t, xt):
    # Compute the noise
    noise = rademacher(xt.shape, dtype=torch.float32, device=device)
    # Compute the jvp of the nabla_Ut and the noise
    jvp = torch.autograd.grad(nabla_Ut, xt, noise, create_graph=True)[0] # nabla(nabla_Ut) * noise
    
    laplacian = (jvp * noise).sum(-1)
    return laplacian

# %%
class VEReverse_coupled(torch.nn.Module):
    noise_type = "diagonal"
    sde_type = "ito"

    def __init__(self, model, noise_schedule):
        super().__init__()
        self.model = model
        self.noise_schedule = noise_schedule

    def f(self, t, x, resampling_interval=None):
        if t.dim() == 0:
            # repeat the same time for all points if we have a scalar time
            t = t * torch.ones(x.shape[0]).to(x.device)

        with torch.enable_grad():
            x.requires_grad_(True)
            t.requires_grad_(True)
            epsilon_t = self.g(t, x).pow(2) / 2 

            Ut = self.model(t, x)
            nabla_Ut = torch.autograd.grad(Ut.sum(), x, create_graph=True)[0]
            drift_X = nabla_Ut * self.g(t, x).pow(2).unsqueeze(-1)

            drift_A = torch.zeros(x.shape[0]).to(x.device)

            if resampling_interval is None:
                return  drift_X, drift_A

            dUt_dt = torch.autograd.grad(Ut.sum(), t, create_graph=True)[0]

            laplacian_b = epsilon_t * compute_laplacian(self.model, t, x)
            drift_A = laplacian_b + epsilon_t * nabla_Ut.pow(2).sum(-1)  + dUt_dt

        return  drift_X, drift_A

    def g(self, t, x):
        g = self.noise_schedule.g(t)
        return g

def euler_maruyama_step_coupled(sde, x, t, a, dt, step, resampling_interval):
    # Calculate drift and diffusion terms
    drift_Xt, drift_At = sde.f(t, x, resampling_interval)
    drift_Xt = drift_Xt * dt
    drift_At = drift_At * dt

    if t.dim() == 0:
        # repeat the same time for all points if we have a scalar time
        t = t * torch.ones_like(x).to(device)
    diffusion = sde.g(t, x) * np.sqrt(dt) * torch.randn_like(x).to(device)

    # Update the state
    x_next = x + drift_Xt + diffusion
    a_next = a + drift_At

    if resampling_interval is None or step % resampling_interval != 0:
        return x_next, a_next, a_next

    #resample based on the weights
    choice = torch.multinomial(torch.exp(-a_next), x.shape[0], replacement=True)
    a_next_plot = a_next.clone()
    a_next = torch.zeros_like(a_next)
    x_next = x_next[choice]
    
    return x_next, a_next, a_next_plot


def integrate_sde_coupled(sde, x0, t_span, dt, resampling_interval):
    times = torch.arange(t_span[0], t_span[1], dt).to(device)
    x = x0
    x0.requires_grad = True
    samples = []
    logweights = []
    a = torch.zeros(x.shape[0]).to(device)
    with torch.no_grad():
        for step, t in enumerate(times):
            x, a, a_next_plot = euler_maruyama_step_coupled(sde, x, 1-t, a, dt, step, resampling_interval)
            samples.append(x)
            logweights.append(a_next_plot)
    return torch.stack(samples), torch.stack(logweights)


def generate_samples_weighted(reverse_sde, num_samples, t_span=(0, 1), resampling_interval=None):
    integrator = integrate_sde_coupled
    samples = prior.sample(num_samples)

    samples, weights = integrator(
        sde=reverse_sde,
        x0=samples,
        t_span=t_span,
        dt=1e-2,
        resampling_interval = resampling_interval,
    )
    return samples[-1], weights

# %%
# sample from a tensor
def sample_from_tensor(tensor, num_samples):
    idx = torch.randint(0, tensor.shape[0], (num_samples,))
    return tensor[idx]


# calculate the log expectation of the reward
def log_E_R(_x, _t, energy, noise_schedule, num_mc_samples):
    repeated_x = _x.unsqueeze(0).repeat_interleave(num_mc_samples, dim=0)
    repeated_t = _t.unsqueeze(0).repeat_interleave(num_mc_samples, dim=0)
    h_t  = noise_schedule.h(repeated_t) 
    h_t = h_t.unsqueeze(1)

    samples = repeated_x + torch.randn(repeated_x.shape).to(device) * (h_t ** 0.5)
    # log_rewards = target(target.unnormalize(samples))
    log_rewards = energy(samples)
    log_expectation_R = torch.logsumexp(log_rewards, dim=-1) - np.log(num_mc_samples)
    return log_expectation_R


def estimate_grad_Rt(xt,
                     t,
                     energy,
                     diffusion_samples,
                     noise_schedule,
                     num_mc_samples=100):
    est_scores_n = torch.func.grad(log_E_R)(xt, t, energy, noise_schedule, num_mc_samples)
    return est_scores_n

def estimate_grad_Rt_high_t(xt,
                            t,
                            energy, 
                            diffusion_samples,
                            noise_schedule,
                            num_mc_samples=100):

    repeated_xt = xt.unsqueeze(0)
    h_t  = noise_schedule.h(t)

    q_diffusion_proposal = sample_from_tensor(diffusion_samples, num_mc_samples)
    q_samples = q_diffusion_proposal

    
    with torch.no_grad():         
        log_p_xt = - (torch.linalg.vector_norm((q_samples.to(device) - repeated_xt.repeat(num_mc_samples, 1)), dim=-1) ** 2 
                / (2 * h_t.squeeze()))          
        log_weights = log_p_xt
        denoising_score = - ((repeated_xt.repeat(num_mc_samples, 1) - q_samples) 
                         / h_t.squeeze())
        scores = denoising_score 

    estimate = torch.sum(torch.nn.functional.softmax(log_weights, dim=0)[:, None] * scores, dim=0)
    return estimate


def estimate_grad_Rt_low_t(xt,
                           t,
                           energy,
                           diffusion_samples,
                           noise_schedule,
                           num_mc_samples=100):
    repeated_xt = xt.unsqueeze(0)
    h_t  = noise_schedule.h(t)
    device = xt.device
    
    q_normal_proposal = repeated_xt + torch.randn((num_mc_samples,) + xt.size()).to(device) * (h_t ** 0.5)
    q_samples = q_normal_proposal
    
    with torch.no_grad():
        log_p_pre = energy(q_samples)
        log_weights = log_p_pre
        target_score  = torch.vmap(torch.func.grad(lambda x: energy(x)))(q_samples)
        scores = target_score

    estimate = torch.sum(torch.nn.functional.softmax(log_weights, dim=0)[:, None] * scores, dim=0)
    return estimate

# %%
def reward_matching_loss(estimator,
                         model,
                         energy,
                         x,
                         t,
                         diffusion_samples,
                         noise_schedule,
                         num_mc_samples=100,
                         clip=True
    ):


    x.requires_grad = True

    h_t = noise_schedule.h(t.unsqueeze(1))
    
    # noisy sample: x(t)
    xt = torch.normal(x, h_t**0.5)

    # predicted score
    pred_energy = model(t, xt)

    pred_scores = torch.autograd.grad(
        pred_energy.sum(), xt, create_graph=True
    )[0]

    estimated_scores = torch.vmap(estimator, randomness="different",
                                  in_dims=(0, 0, None, None, None))(
                                    xt,
                                    t,
                                    energy,
                                    diffusion_samples,
                                    noise_schedule,
                                    num_mc_samples=num_mc_samples,
                                ).detach()


    if clip:
        estimated_scores = clipper.clip_scores(estimated_scores)

    err = (
        estimated_scores - pred_scores
    ) ** 2
    return err.mean()

# %% [markdown]
# ### Energy Model

# %%
from torch import nn
class EnergyNet(nn.Module):
    def __init__(
        self, 
        score_net: nn.Module,
    ):
        super(EnergyNet, self).__init__()
        self.score_net = score_net

    def forward(self, t: torch.Tensor, x: torch.Tensor) -> torch.Tensor:
        # parametrize energy as <score_net(t, x), x>
        return torch.sum(self.score_net(t, x) * x, dim=1)

    def forward_score(self, t: torch.Tensor, x: torch.Tensor) -> torch.Tensor:
        return self.score_net(t, x)

# %% [markdown]
# ### Training

# %%
from src.models.components.noise_schedules import GeometricNoiseSchedule
noise_schedule = GeometricNoiseSchedule(sigma_min=0.01, sigma_max=3)

# %%
prior = MeanFreePrior(n_particles, spatial_dim, device=device, scale = noise_schedule.h(1) ** 0.5)
x1_samples = prior.sample(1000).detach().cpu()
plt.scatter(x1_samples[:, 0], x1_samples[:, 1], s=3)

# %%
from src.models.components.prioritised_replay_buffer import SimpleBuffer
buffer = SimpleBuffer(
    dimensionality,
    10000,
    1000,
    initial_sampler=None,
    device=device,
    fill_buffer_during_init=False,
    sample_with_replacement=True,
    prioritize=False,
)
# Out:
# Buffer not initialised, expected that checkpoint will be loaded.

# %%
clipper = Clipper(
    should_clip_scores=True, should_clip_log_rewards=False, max_score_norm=20
)

# %%
t_switch_estimators = 0.7
outer_epochs= 100
inner_epochs = 100

batch_size = 512

x1_samples_energy = target(x1_samples.detach())
buffer.add(x1_samples, x1_samples_energy)

train_dataset = TensorDataset(x1_samples.detach(), x1_samples_energy.clone())
trainloader = DataLoader(train_dataset, batch_size = batch_size, shuffle=True) 

num_mc_samples = 200

# %%
from src.models.components.egnn import EGNN_dynamics
score_net = EGNN_dynamics(n_particles=target.n_particles,
                          n_dimension=target.n_spatial_dim,
                          hidden_nf=32,
                          act_fn=torch.nn.SiLU(),
                          n_layers=3,
                          recurrent=True,
                          tanh=True,
                          attention=True,
                          condition_time=True,
                          agg='sum').to(device)


model = EnergyNet(score_net).to(device)
optimizer = Adam(model.parameters(), lr=1e-3)
weighted = False

# %%
for epoch in tqdm(range(outer_epochs)):
    for epoch in range(inner_epochs):
        total_loss = 0.
        for samples,_ in trainloader:
            samples = samples.to(device)


            samples_high_t = samples[:batch_size//2]
            samples_low_t = samples[batch_size//2:]
            
            optimizer.zero_grad()

            t = torch.rand(len(samples)).to(device)
            t_high = t[:batch_size//2] * (1-t_switch_estimators) + t_switch_estimators
            t_low = t[batch_size//2:] * t_switch_estimators

            rm_loss_high_t = reward_matching_loss(estimate_grad_Rt,
                                                  model, 
                                                  target,
                                                  samples_high_t,
                                                  t_high, 
                                                  samples,
                                                  noise_schedule, 
                                                  num_mc_samples=num_mc_samples,
                                                  ) 
            
            rm_loss_low_t = reward_matching_loss(estimate_grad_Rt,
                                                  model, 
                                                  target,
                                                  samples_low_t,
                                                  t_low, 
                                                  samples,
                                                  noise_schedule, 
                                                  num_mc_samples=num_mc_samples,
                                                  )
            

            
            loss = rm_loss_high_t.mean() + rm_loss_low_t.mean()
            total_loss += loss.item()
            loss.backward()
            optimizer.step()
            
        if epoch % 49 == 0:
            print("Epoch %d | Loss %f" % (epoch, loss.item()))
            ve_reverse_sde = VEReverse_coupled(model, noise_schedule)
            samples_weighted, log_weights = generate_samples_weighted(ve_reverse_sde, 1000, t_span=(0, 1), resampling_interval=1)
            target.get_dataset_fig(samples_weighted)
            plt.show()

            ve_reverse_sde = VEReverse_coupled(model, noise_schedule)
            samples, _ = generate_samples_weighted(ve_reverse_sde, 1000, t_span=(0, 1), resampling_interval=None)

            target.get_dataset_fig(samples)
            plt.show()


    # Generate samples using the network
    ve_reverse_sde = VEReverse_coupled(model, noise_schedule)
    samples, log_weights = generate_samples_weighted(ve_reverse_sde, 1000, t_span=(0, 1), resampling_interval=1)
    samples_energy = target(samples)

    # Update Buffer 
    buffer.add(samples, samples_energy)

    print("Mean of Energy", samples_energy.mean())
    
    # target.get_dataset_fig(samples)
    # plt.show()

    # Resample data from the buffer
    samples, samples_energy, _ = buffer.sample(512 * 10)
    train_dataset = TensorDataset(samples, samples_energy)
    trainloader = DataLoader(train_dataset, batch_size = 512, shuffle=True)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 0 | Loss 74.205803
# /home/mila/t/tara.akhoundsadegh/active_inference/runner/src/models/components/egnn.py:325: UserWarning: There is a performance drop because we have not yet implemented the batching rule for aten::scatter_add_. Please file us an issue on GitHub so that we can prioritize its implementation. (Triggered internally at /opt/conda/conda-bld/pytorch_1720538438429/work/aten/src/ATen/functorch/BatchedFallback.cpp:81.)
#   result.scatter_add_(0, segment_ids, data)
# Epoch 49 | Loss 27.529316
# Epoch 98 | Loss 25.261944
#   1%|          | 1/100 [01:11<1:57:49, 71.41s/it]
# Mean of Energy tensor(22.3941, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch 0 | Loss 22.209049
# Epoch 49 | Loss 19.083033
# Epoch 98 | Loss 20.533340
#   2%|▏         | 2/100 [03:00<2:32:30, 93.37s/it]
# Mean of Energy tensor(23.7824, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch 0 | Loss 20.868164
# Epoch 49 | Loss 22.019941
# Epoch 98 | Loss 19.559942
#   2%|▏         | 2/100 [04:45<3:53:22, 142.88s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 60
#      58 # Generate samples using the network
#      59 ve_reverse_sde = VEReverse_coupled(model, noise_schedule)
# ---> 60 samples, log_weights = generate_samples_weighted(ve_reverse_sde, 1000, t_span=(0, 1), resampling_interval=1)
#      61 samples_energy = target(samples)
#      63 # Update Buffer
#
# Cell In[9], line 86, in generate_samples_weighted(reverse_sde, num_samples, t_span, resampling_interval)
#      83 integrator = integrate_sde_coupled
#      84 samples = prior.sample(num_samples)
# ---> 86 samples, weights = integrator(
#      87     sde=reverse_sde,
#      88     x0=samples,
#      89     t_span=t_span,
#      90     dt=1e-2,
#      91     resampling_interval = resampling_interval,
#      92 )
#      93 return samples[-1], weights
#
# Cell In[9], line 76, in integrate_sde_coupled(sde, x0, t_span, dt, resampling_interval)
#      74 with torch.no_grad():
#      75     for step, t in enumerate(times):
# ---> 76         x, a, a_next_plot = euler_maruyama_step_coupled(sde, x, 1-t, a, dt, step, resampling_interval)
#      77         samples.append(x)
#      78         logweights.append(a_next_plot)
#
# Cell In[9], line 42, in euler_maruyama_step_coupled(sde, x, t, a, dt, step, resampling_interval)
#      40 def euler_maruyama_step_coupled(sde, x, t, a, dt, step, resampling_interval):
#      41     # Calculate drift and diffusion terms
# ---> 42     drift_Xt, drift_At = sde.f(t, x, resampling_interval)
#      43     drift_Xt = drift_Xt * dt
#      44     drift_At = drift_At * dt
#
# Cell In[9], line 31, in VEReverse_coupled.f(self, t, x, resampling_interval)
#      27         return  drift_X, drift_A
#      29     dUt_dt = torch.autograd.grad(Ut.sum(), t, create_graph=True)[0]
# ---> 31     laplacian_b = epsilon_t * compute_laplacian(self.model, t, x)
#      32     drift_A = laplacian_b + epsilon_t * nabla_Ut.pow(2).sum(-1)  + dUt_dt
#      34 return  drift_X, drift_A
#
# Cell In[6], line 7, in compute_laplacian(model, t, xt)
#       4     return model(t.unsqueeze(0), xt.unsqueeze(0)).squeeze()
#       6 # Calculate the Hessian matrix of the model output with respect to the input
# ----> 7 hessian_matrix = vmap(hessian(func_wrap, argnums=1))(t, xt)
#       9 # Calculate the Laplacian as the trace of the Hessian matrix
#      10 laplacian = hessian_matrix.diagonal(offset=0, dim1=-2, dim2=-1).sum(dim=-1)
#
# File ~/scratch/demenv/lib/python3.10/site-packages/torch/_functorch/apis.py:201, in vmap.<locals>.wrapped(*args, **kwargs)
#     200 def wrapped(*args, **kwargs):
# --> 201     return vmap_impl(
#     202         func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs
#     203     )
#
# File ~/scratch/demenv/lib/python3.10/site-packages/torch/_functorch/vmap.py:331, in vmap_impl(func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs)
#     320     return _chunked_vmap(
#     321         func,
#     322         flat_in_dims,
#    (...)
#     327         **kwargs,
#     328     )
#     330 # If chunk_size is not specified.
# --> 331 return _flat_vmap(
#     332     func,
#     333     batch_size,
#     334     flat_in_dims,
#     335     flat_args,
#     336     args_spec,
#     337     out_dims,
#     338     randomness,
#     339     **kwargs,
#     340 )
#
# File ~/scratch/demenv/lib/python3.10/site-packages/torch/_functorch/vmap.py:48, in doesnt_support_saved_tensors_hooks.<locals>.fn(*args, **kwargs)
#      45 @functools.wraps(f)
#      46 def fn(*args, **kwargs):
#      47     with torch.autograd.graph.disable_saved_tensors_hooks(message):
# ---> 48         return f(*args, **kwargs)
#
# File ~/scratch/demenv/lib/python3.10/site-packages/torch/_functorch/vmap.py:480, in _flat_vmap(func, batch_size, flat_in_dims, flat_args, args_spec, out_dims, randomness, **kwargs)
#     476 with vmap_increment_nesting(batch_size, randomness) as vmap_level:
#     477     batched_inputs = _create_batched_inputs(
#     478         flat_in_dims, flat_args, vmap_level, args_spec
#     479     )
# --> 480     batched_outputs = func(*batched_inputs, **kwargs)
#     481     return _unwrap_batched(batched_outputs, out_dims, vmap_level, batch_size, func)
#
# File ~/scratch/demenv/lib/python3.10/site-packages/torch/_functorch/eager_transforms.py:1312, in jacfwd.<locals>.wrapper_fn(*args)
#    1309     _, jvp_out = output
#    1310     return jvp_out
# -> 1312 results = vmap(push_jvp, randomness=randomness)(basis)
#    1313 if has_aux:
#    1314     results, aux = results
#
# File ~/scratch/demenv/lib/python3.10/site-packages/torch/_functorch/apis.py:201, in vmap.<locals>.wrapped(*args, **kwargs)
#     200 def wrapped(*args, **kwargs):
# --> 201     return vmap_impl(
#     202         func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs
#     203     )
#
# File ~/scratch/demenv/lib/python3.10/site-packages/torch/_functorch/vmap.py:331, in vmap_impl(func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs)
#     320     return _chunked_vmap(
#     321         func,
#     322         flat_in_dims,
#    (...)
#     327         **kwargs,
#     328     )
#     330 # If chunk_size is not specified.
# --> 331 return _flat_vmap(
#     332     func,
#     333     batch_size,
#     334     flat_in_dims,
#     335     flat_args,
#     336     args_spec,
#     337     out_dims,
#     338     randomness,
#     339     **kwargs,
#     340 )
#
# File ~/scratch/demenv/lib/python3.10/site-packages/torch/_functorch/vmap.py:48, in doesnt_support_saved_tensors_hooks.<locals>.fn(*args, **kwargs)
#      45 @functools.wraps(f)
#      46 def fn(*args, **kwargs):
#      47     with torch.autograd.graph.disable_saved_tensors_hooks(message):
# ---> 48         return f(*args, **kwargs)
#
# File ~/scratch/demenv/lib/python3.10/site-packages/torch/_functorch/vmap.py:480, in _flat_vmap(func, batch_size, flat_in_dims, flat_args, args_spec, out_dims, randomness, **kwargs)
#     476 with vmap_increment_nesting(batch_size, randomness) as vmap_level:
#     477     batched_inputs = _create_batched_inputs(
#     478         flat_in_dims, flat_args, vmap_level, args_spec
#     479     )
# --> 480     batched_outputs = func(*batched_inputs, **kwargs)
#     481     return _unwrap_batched(batched_outputs, out_dims, vmap_level, batch_size, func)
#
# File ~/scratch/demenv/lib/python3.10/site-packages/torch/_functorch/eager_transforms.py:1301, in jacfwd.<locals>.wrapper_fn.<locals>.push_jvp(basis)
#    1300 def push_jvp(basis):
# -> 1301     output = _jvp_with_argnums(
#    1302         func, args, basis, argnums=argnums, has_aux=has_aux
#    1303     )
#    1304     # output[0] is the output of `func(*args)`
#    1305     error_if_complex("jacfwd", output[0], is_input=False)
#
# File ~/scratch/demenv/lib/python3.10/site-packages/torch/_functorch/vmap.py:48, in doesnt_support_saved_tensors_hooks.<locals>.fn(*args, **kwargs)
#      45 @functools.wraps(f)
#      46 def fn(*args, **kwargs):
#      47     with torch.autograd.graph.disable_saved_tensors_hooks(message):
# ---> 48         return f(*args, **kwargs)
#
# File ~/scratch/demenv/lib/python3.10/site-packages/torch/_functorch/eager_transforms.py:1141, in _jvp_with_argnums(func, primals, tangents, argnums, strict, has_aux)
#    1139     primals = _wrap_all_tensors(primals, level)
#    1140     duals = _replace_args(primals, duals, argnums)
# -> 1141 result_duals = func(*duals)
#    1142 if has_aux:
#    1143     if not (isinstance(result_duals, tuple) and len(result_duals) == 2):
#
# File ~/scratch/demenv/lib/python3.10/site-packages/torch/_functorch/eager_transforms.py:605, in jacrev.<locals>.wrapper_fn(*args)
#     603 def wrapper_fn(*args):
#     604     error_if_complex("jacrev", args, is_input=True)
# --> 605     vjp_out = _vjp_with_argnums(func, *args, argnums=argnums, has_aux=has_aux)
#     606     if has_aux:
#     607         output, vjp_fn, aux = vjp_out
#
# File ~/scratch/demenv/lib/python3.10/site-packages/torch/_functorch/vmap.py:48, in doesnt_support_saved_tensors_hooks.<locals>.fn(*args, **kwargs)
#      45 @functools.wraps(f)
#      46 def fn(*args, **kwargs):
#      47     with torch.autograd.graph.disable_saved_tensors_hooks(message):
# ---> 48         return f(*args, **kwargs)
#
# File ~/scratch/demenv/lib/python3.10/site-packages/torch/_functorch/eager_transforms.py:400, in _vjp_with_argnums(func, argnums, has_aux, *primals)
#     398     diff_primals = _slice_argnums(primals, argnums, as_tuple=False)
#     399     tree_map_(partial(_create_differentiable, level=level), diff_primals)
# --> 400 primals_out = func(*primals)
#     402 if has_aux:
#     403     if not (isinstance(primals_out, tuple) and len(primals_out) == 2):
#
# Cell In[6], line 4, in compute_laplacian.<locals>.func_wrap(t, xt)
#       3 def func_wrap(t, xt):
# ----> 4     return model(t.unsqueeze(0), xt.unsqueeze(0)).squeeze()
#
# File ~/scratch/demenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/scratch/demenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# Cell In[12], line 12, in EnergyNet.forward(self, t, x)
#      10 def forward(self, t: torch.Tensor, x: torch.Tensor) -> torch.Tensor:
#      11     # parametrize energy as <score_net(t, x), x>
# ---> 12     return torch.sum(self.score_net(t, x) * x, dim=1)
#
# File ~/scratch/demenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/scratch/demenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/active_inference/runner/src/models/components/egnn.py:55, in EGNN_dynamics.forward(self, t, xs)
#      53 h = h.reshape(n_batch * self._n_particles, 1)
#      54 edge_attr = torch.sum((x[edges[0]] - x[edges[1]]) ** 2, dim=1, keepdim=True)
# ---> 55 _, x_final = self.egnn(h, x, edges, edge_attr=edge_attr)
#      56 vel = x_final - x
#      58 vel = vel.view(n_batch, self._n_particles, self._n_dimension)
#
# File ~/scratch/demenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/scratch/demenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/active_inference/runner/src/models/components/egnn.py:139, in EGNN.forward(self, h, x, edges, edge_attr, node_mask, edge_mask)
#     137 h = self.embedding(h)
#     138 for i in range(0, self.n_layers):
# --> 139     h, x, _ = self._modules["gcl_%d" % i](
#     140         h,
#     141         edges,
#     142         x,
#     143         edge_attr=edge_attr,
#     144         node_mask=node_mask,
#     145         edge_mask=edge_mask,
#     146     )
#     147 h = self.embedding_out(h)
#     149 # Important, the bias of the last linear might be non-zero
#
# File ~/scratch/demenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/scratch/demenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/active_inference/runner/src/models/components/egnn.py:296, in E_GCL.forward(self, h, edge_index, coord, edge_attr, node_attr, node_mask, edge_mask)
#     293 radial, coord_diff = self.coord2radial(edge_index, coord)
#     295 edge_feat = self.edge_model(h[row], h[col], radial, edge_attr, edge_mask)
# --> 296 coord = self.coord_model(
#     297     coord, edge_index, coord_diff, radial, edge_feat, node_mask, edge_mask
#     298 )
#     300 h, agg = self.node_model(h, edge_index, edge_feat, node_attr)
#     301 # coord = self.node_coord_model(h, coord)
#     302 # x = self.node_model(x, edge_index, x[col], u, batch)  # GCN
#     303 # print("h", h)
#
# File ~/active_inference/runner/src/models/components/egnn.py:265, in E_GCL.coord_model(self, coord, edge_index, coord_diff, radial, edge_feat, node_mask, edge_mask)
#     262     trans = trans * edge_mask
#     264 if self.agg_type == "sum":
# --> 265     agg = unsorted_segment_sum(trans, row, num_segments=coord.size(0))
#     266 elif self.agg_type == "mean":
#     267     if node_mask is not None:
#     268         # raise Exception('This part must be debugged before use')
#
# File ~/active_inference/runner/src/models/components/egnn.py:325, in unsorted_segment_sum(data, segment_ids, num_segments)
#     323 result = data.new_full(result_shape, 0)  # Init empty result tensor.
#     324 segment_ids = segment_ids.unsqueeze(-1).expand(-1, data.size(1))
# --> 325 result.scatter_add_(0, segment_ids, data)
#     326 return result
#
# KeyboardInterrupt:

# %%
# Generate samples using the network
ve_reverse_sde = VEReverse_coupled(model, noise_schedule)
samples, log_weights = generate_samples_weighted(ve_reverse_sde, 1000, t_span=(0, 1))
samples_energy = target(samples)
print(log_weights.shape)
# Out:
# /home/mila/t/tara.akhoundsadegh/active_inference/runner/src/models/components/egnn.py:325: UserWarning: There is a performance drop because we have not yet implemented the batching rule for aten::scatter_add_. Please file us an issue on GitHub so that we can prioritize its implementation. (Triggered internally at /opt/conda/conda-bld/pytorch_1720538438429/work/aten/src/ATen/functorch/BatchedFallback.cpp:81.)
#   result.scatter_add_(0, segment_ids, data)
# torch.Size([100, 1000])

# %%
log_weights[-1].exp().shape
# Out:
# torch.Size([1000])

# %%
target.get_dataset_fig(samples, (-log_weights[-1]).exp().clamp(0, 1000));
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 target.get_dataset_fig(samples, (-log_weights[-1]).exp().clamp(0, 1000));
#
# TypeError: MultiDoubleWellEnergy.get_dataset_fig() takes 2 positional arguments but 3 were given

# %%
log_weights[-1].exp().clamp(0, 10)
# Out:
# tensor(6.0095, device='cuda:0')

# %%
log_weights
# Out:
# tensor([[ 8.2919e+00, -2.2061e-02, -5.0880e-01,  ..., -2.3879e-01,
#           3.3873e-01,  2.7666e-01],
#         [-2.2786e-01,  2.1849e-01,  3.0075e-01,  ..., -7.2196e-02,
#           3.3647e-01, -1.1640e+00],
#         [-3.9551e-01,  3.9372e-01, -2.7624e-01,  ..., -1.6349e-02,
#           4.3026e-01,  3.4315e-02],
#         ...,
#         [-8.5920e-04, -8.3281e-04, -3.9601e-04,  ..., -2.1885e-04,
#          -8.5873e-05, -1.0177e-03],
#         [-5.5232e-04, -2.9219e-04, -6.6665e-04,  ..., -5.9011e-04,
#          -4.4063e-04, -6.4956e-04],
#         [-9.1965e-05, -7.2110e-04, -5.5058e-04,  ..., -4.4903e-04,
#           4.3927e-04, -2.6917e-04]], device='cuda:0')

# %%
plt.plot(log_weights[0:, :20].cpu())
# Out:
# [<matplotlib.lines.Line2D at 0x7fb6eb51e560>,
#  <matplotlib.lines.Line2D at 0x7fb6eb580250>,
#  <matplotlib.lines.Line2D at 0x7fb6eb580340>,
#  <matplotlib.lines.Line2D at 0x7fb6eb580430>,
#  <matplotlib.lines.Line2D at 0x7fb6eb580520>,
#  <matplotlib.lines.Line2D at 0x7fb6eb580610>,
#  <matplotlib.lines.Line2D at 0x7fb6eb580700>,
#  <matplotlib.lines.Line2D at 0x7fb6eb5807f0>,
#  <matplotlib.lines.Line2D at 0x7fb6eb5808e0>,
#  <matplotlib.lines.Line2D at 0x7fb6eb5809d0>,
#  <matplotlib.lines.Line2D at 0x7fb6eb580ac0>,
#  <matplotlib.lines.Line2D at 0x7fb6eb580bb0>,
#  <matplotlib.lines.Line2D at 0x7fb6eb580ca0>,
#  <matplotlib.lines.Line2D at 0x7fb6eb580d90>,
#  <matplotlib.lines.Line2D at 0x7fb6eb580e80>,
#  <matplotlib.lines.Line2D at 0x7fb6eb580f70>,
#  <matplotlib.lines.Line2D at 0x7fb6eb581060>,
#  <matplotlib.lines.Line2D at 0x7fb6eb581150>,
#  <matplotlib.lines.Line2D at 0x7fb6eb581240>,
#  <matplotlib.lines.Line2D at 0x7fb6eb581330>]
